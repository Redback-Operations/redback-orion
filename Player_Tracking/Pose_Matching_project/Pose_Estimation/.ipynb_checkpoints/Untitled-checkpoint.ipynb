# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
net = cv.dnn.readNetFromTensorflow("graph_opt.pb")

# %%
inWidth = 368
inHeight = 368
thr = 0.2

# %%
BODY_PARTS = { "Nose": 0, "Neck": 1, "RShoulder": 2, "RElbow": 3, "RWrist": 4,
               "LShoulder": 5, "LElbow": 6, "LWrist": 7, "RHip": 8, "RKnee": 9,
               "RAnkle": 10, "LHip": 11, "LKnee": 12, "LAnkle": 13, "REye": 14,
               "LEye": 15, "REar": 16, "LEar": 17, "Background": 18 }

POSE_PAIRS = [ ["Neck", "RShoulder"], ["Neck", "LShoulder"], ["RShoulder", "RElbow"],
               ["RElbow", "RWrist"], ["LShoulder", "LElbow"], ["LElbow", "LWrist"],
               ["Neck", "RHip"], ["RHip", "RKnee"], ["RKnee", "RAnkle"], ["Neck", "LHip"],
               ["LHip", "LKnee"], ["LKnee", "LAnkle"], ["Neck", "Nose"], ["Nose", "REye"],
               ["REye", "REar"], ["Nose", "LEye"], ["LEye", "LEar"] ]

# %%
img = cv.imread("pose1.jpg")

# %%
plt.imshow(img)

# %%
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %%
#255/2 = 127.5
def pose_estimation(frame):
    frameWidth = frame.shape[1]
    frameHeight = frame.shape[0]
    net.setInput(cv.dnn.blobFromImage(frame, 1.0, (inWidth, inHeight), (127.5, 127.5, 127.5), swapRB=True, crop=False))
    out = net.forward()
    out = out[:, :19, :, :]

    assert(len(BODY_PARTS) == out.shape[1])

    points = []

    for i in range(len(BODY_PARTS)):
        heatMap = out[0, i, :, :]
        _, conf, _, point = cv.minMaxLoc(heatMap)
        print(f"Body part {i}: Confidence = {conf}, Point = {point}")
        x = (frameWidth * point[0]) / out.shape[3]
        y = (frameHeight * point[1]) / out.shape[2]

        # Add a point if it's confidence is higher than threshold.
        points.append((int(x), int(y)) if conf > thr else None)

    for pair in POSE_PAIRS:
        partFrom = pair[0]
        partTo = pair[1]
        assert(partFrom in BODY_PARTS)
        assert(partTo in BODY_PARTS)

        idFrom = BODY_PARTS[partFrom]
        idTo = BODY_PARTS[partTo]

        if points[idFrom] and points[idTo]:
            cv.line(frame, points[idFrom], points[idTo], (0, 255, 0), 3)
            cv.ellipse(frame, points[idFrom], (3, 3), 0, 0, 360, (0, 0, 255), cv.FILLED)
            cv.ellipse(frame, points[idTo], (3, 3), 0, 0, 360, (0, 0, 255), cv.FILLED)

    t, _ = net.getPerfProfile()
    freq = cv.getTickFrequency() / 1000
    cv.putText(frame, '%.2fms' % (t / freq), (10, 20), cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0))
    return frame

# %%
estimated_image = pose_estimation(img)
# Out:
# Body part 0: Confidence = 0.7063313722610474, Point = (23, 10)
# Body part 1: Confidence = 0.6726978421211243, Point = (23, 13)
# Body part 2: Confidence = 0.5386507511138916, Point = (18, 13)
# Body part 3: Confidence = 0.3026980757713318, Point = (12, 13)
# Body part 4: Confidence = 0.10182499140501022, Point = (33, 7)
# Body part 5: Confidence = 0.4709925353527069, Point = (26, 13)
# Body part 6: Confidence = 0.4213835299015045, Point = (31, 12)
# Body part 7: Confidence = 0.12100501358509064, Point = (33, 7)
# Body part 8: Confidence = 0.5948360562324524, Point = (20, 24)
# Body part 9: Confidence = 0.4244673252105713, Point = (19, 33)
# Body part 10: Confidence = 0.37972891330718994, Point = (18, 39)
# Body part 11: Confidence = 0.5718606114387512, Point = (25, 24)
# Body part 12: Confidence = 0.6203016042709351, Point = (25, 33)
# Body part 13: Confidence = 0.7371795177459717, Point = (24, 39)
# Body part 14: Confidence = 0.761066734790802, Point = (23, 9)
# Body part 15: Confidence = 0.841649055480957, Point = (24, 9)
# Body part 16: Confidence = 0.7450346946716309, Point = (21, 9)
# Body part 17: Confidence = 0.377780556678772, Point = (25, 9)
# Body part 18: Confidence = 1.0082483291625977, Point = (1, 44)

# %%
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %%
#Video

# %%
#perform this demo on video
#from google.colab.patches import cv2_imshow
cap = cv.VideoCapture('pose_estimation_video.mp4')
cap.set(3,800) #height
cap.set(4,800) #width

if not cap.isOpened():
    cap = cv.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open video")

while cv.waitKey(1) < 0:
    hasFrame,frame = cap.read()
    if not hasFrame:
        cv.waitKey()
        break
        
    frameWidth = frame.shape[1]
    frameHeight = frame.shape[0]
    net.setInput(cv.dnn.blobFromImage(frame, 1.0, (inWidth, inHeight), (127.5, 127.5, 127.5), swapRB=True, crop=False))
    out = net.forward()
    out = out[:, :19, :, :]

    assert(len(BODY_PARTS) == out.shape[1])

    points = []

    for i in range(len(BODY_PARTS)):
        heatMap = out[0, i, :, :]
        _, conf, _, point = cv.minMaxLoc(heatMap)
        print(f"Body part {i}: Confidence = {conf}, Point = {point}")
        x = (frameWidth * point[0]) / out.shape[3]
        y = (frameHeight * point[1]) / out.shape[2]

        # Add a point if it's confidence is higher than threshold.
        points.append((int(x), int(y)) if conf > thr else None)

    for pair in POSE_PAIRS:
        partFrom = pair[0]
        partTo = pair[1]
        assert(partFrom in BODY_PARTS)
        assert(partTo in BODY_PARTS)

        idFrom = BODY_PARTS[partFrom]
        idTo = BODY_PARTS[partTo]

        if points[idFrom] and points[idTo]:
            cv.line(frame, points[idFrom], points[idTo], (0, 255, 0), 3)
            cv.ellipse(frame, points[idFrom], (3, 3), 0, 0, 360, (0, 0, 255), cv.FILLED)
            cv.ellipse(frame, points[idTo], (3, 3), 0, 0, 360, (0, 0, 255), cv.FILLED)

    t, _ = net.getPerfProfile()
    freq = cv.getTickFrequency() / 1000
    cv.putText(frame, '%.2fms' % (t / freq), (10, 20), cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0))

    cv.imshow('Pose Estimation Tutorial', frame)
# Out:
# Body part 0: Confidence = 0.7201645970344543, Point = (25, 11)
# Body part 1: Confidence = 0.5812837481498718, Point = (26, 18)
# Body part 2: Confidence = 0.5603547096252441, Point = (22, 19)
# Body part 3: Confidence = 0.05228233337402344, Point = (22, 29)
# Body part 4: Confidence = 0.019996780902147293, Point = (24, 35)
# Body part 5: Confidence = 0.546015739440918, Point = (29, 18)
# Body part 6: Confidence = 0.10711903870105743, Point = (30, 28)
# Body part 7: Confidence = 0.016977794468402863, Point = (25, 35)
# Body part 8: Confidence = 0.08100104331970215, Point = (24, 34)
# Body part 9: Confidence = 0.011311421170830727, Point = (26, 10)
# Body part 10: Confidence = 0.007496107369661331, Point = (24, 10)
# Body part 11: Confidence = 0.0723024308681488, Point = (27, 35)
# Body part 12: Confidence = 0.010864434763789177, Point = (26, 11)
# Body part 13: Confidence = 0.008833315223455429, Point = (45, 1)
# Body part 14: Confidence = 0.7318204641342163, Point = (24, 10)
# Body part 15: Confidence = 0.7476478219032288, Point = (25, 10)
# Body part 16: Confidence = 0.4620991051197052, Point = (23, 10)
# Body part 17: Confidence = 0.6667735576629639, Point = (27, 11)
# Body part 18: Confidence = 1.0043433904647827, Point = (0, 0)
# Body part 0: Confidence = 0.6867642402648926, Point = (24, 10)
# Body part 1: Confidence = 0.5639125108718872, Point = (26, 18)
# Body part 2: Confidence = 0.5421210527420044, Point = (22, 18)
# Body part 3: Confidence = 0.04582025483250618, Point = (21, 29)
# Body part 4: Confidence = 0.03897780179977417, Point = (24, 35)
# Body part 5: Confidence = 0.47675976157188416, Point = (29, 18)
# Body part 6: Confidence = 0.16710950434207916, Point = (30, 29)
# Body part 7: Confidence = 0.10741075873374939, Point = (25, 36)
# Body part 8: Confidence = 0.06551721692085266, Point = (24, 34)
# Body part 9: Confidence = 0.013297565281391144, Point = (24, 9)
# Body part 10: Confidence = 0.006315724924206734, Point = (43, 33)
# Body part 11: Confidence = 0.11273781955242157, Point = (26, 38)
# Body part 12: Confidence = 0.009297630749642849, Point = (26, 11)
# Body part 13: Confidence = 0.008851712569594383, Point = (45, 1)
# Body part 14: Confidence = 0.725512683391571, Point = (24, 9)
# Body part 15: Confidence = 0.7758991122245789, Point = (25, 9)
# Body part 16: Confidence = 0.3948540687561035, Point = (23, 10)
# Body part 17: Confidence = 0.6763736009597778, Point = (27, 10)
# Body part 18: Confidence = 1.004469394683838, Point = (44, 30)
# Body part 0: Confidence = 0.7345669865608215, Point = (25, 10)
# Body part 1: Confidence = 0.5763475894927979, Point = (26, 18)
# Body part 2: Confidence = 0.5627742409706116, Point = (22, 18)
# Body part 3: Confidence = 0.2027105689048767, Point = (17, 38)
# Body part 4: Confidence = 0.024397840723395348, Point = (18, 37)
# Body part 5: Confidence = 0.46296778321266174, Point = (29, 18)
# Body part 6: Confidence = 0.2298501878976822, Point = (31, 29)
# Body part 7: Confidence = 0.137077197432518, Point = (26, 36)
# Body part 8: Confidence = 0.05246817693114281, Point = (23, 39)
# Body part 9: Confidence = 0.00953604280948639, Point = (26, 10)
# Body part 10: Confidence = 0.00719168595969677, Point = (24, 10)
# Body part 11: Confidence = 0.1022026315331459, Point = (26, 38)
# Body part 12: Confidence = 0.010306120850145817, Point = (26, 41)
# Body part 13: Confidence = 0.008875535801053047, Point = (45, 2)
# Body part 14: Confidence = 0.7561245560646057, Point = (24, 9)
# Body part 15: Confidence = 0.8049290776252747, Point = (25, 9)
# Body part 16: Confidence = 0.4336528480052948, Point = (23, 10)
# Body part 17: Confidence = 0.702793538570404, Point = (27, 10)
# Body part 18: Confidence = 1.0044673681259155, Point = (44, 30)
# Body part 0: Confidence = 0.7837709784507751, Point = (25, 10)
# Body part 1: Confidence = 0.5969558358192444, Point = (26, 18)
# Body part 2: Confidence = 0.5759183764457703, Point = (22, 18)
# Body part 3: Confidence = 0.04448259621858597, Point = (20, 28)
# Body part 4: Confidence = 0.0497642382979393, Point = (24, 35)
# Body part 5: Confidence = 0.5194560289382935, Point = (29, 18)
# Body part 6: Confidence = 0.26846787333488464, Point = (31, 29)
# Body part 7: Confidence = 0.2734183073043823, Point = (26, 36)
# Body part 8: Confidence = 0.09494912624359131, Point = (23, 36)
# Body part 9: Confidence = 0.010087279602885246, Point = (23, 38)
# Body part 10: Confidence = 0.006779907271265984, Point = (43, 2)
# Body part 11: Confidence = 0.20062097907066345, Point = (26, 37)
# Body part 12: Confidence = 0.010631956160068512, Point = (26, 42)
# Body part 13: Confidence = 0.009032737463712692, Point = (45, 1)
# Body part 14: Confidence = 0.7357234954833984, Point = (24, 9)
# Body part 15: Confidence = 0.7948763370513916, Point = (25, 9)
# Body part 16: Confidence = 0.49741536378860474, Point = (23, 10)
# Body part 17: Confidence = 0.6822845339775085, Point = (27, 10)
# Body part 18: Confidence = 1.0045125484466553, Point = (44, 30)
# Body part 0: Confidence = 0.7949299812316895, Point = (25, 10)
# Body part 1: Confidence = 0.6130103468894958, Point = (26, 18)
# Body part 2: Confidence = 0.6090720295906067, Point = (22, 18)
# Body part 3: Confidence = 0.07970745861530304, Point = (18, 30)
# Body part 4: Confidence = 0.044134922325611115, Point = (24, 35)
# Body part 5: Confidence = 0.5272933840751648, Point = (29, 18)
# Body part 6: Confidence = 0.25454840064048767, Point = (31, 29)
# Body part 7: Confidence = 0.17279937863349915, Point = (26, 36)
# Body part 8: Confidence = 0.04292035847902298, Point = (23, 37)
# Body part 9: Confidence = 0.009910399094223976, Point = (26, 10)
# Body part 10: Confidence = 0.009336419403553009, Point = (13, 33)
# Body part 11: Confidence = 0.17855915427207947, Point = (26, 38)
# Body part 12: Confidence = 0.009518571197986603, Point = (26, 11)
# Body part 13: Confidence = 0.009855594485998154, Point = (13, 33)
# Body part 14: Confidence = 0.7374818325042725, Point = (24, 9)
# Body part 15: Confidence = 0.7931902408599854, Point = (25, 9)
# Body part 16: Confidence = 0.4427846372127533, Point = (23, 10)
# Body part 17: Confidence = 0.6595668196678162, Point = (27, 10)
# Body part 18: Confidence = 1.004422664642334, Point = (44, 30)
# Body part 0: Confidence = 0.7859939932823181, Point = (25, 10)
# Body part 1: Confidence = 0.5572604537010193, Point = (26, 18)
# Body part 2: Confidence = 0.5571117997169495, Point = (22, 18)
# Body part 3: Confidence = 0.08708889782428741, Point = (20, 28)
# Body part 4: Confidence = 0.10169798880815506, Point = (19, 28)
# Body part 5: Confidence = 0.4948295056819916, Point = (29, 18)
# Body part 6: Confidence = 0.20148111879825592, Point = (31, 29)
# Body part 7: Confidence = 0.12957973778247833, Point = (25, 35)
# Body part 8: Confidence = 0.028748590499162674, Point = (24, 34)
# Body part 9: Confidence = 0.009333185851573944, Point = (26, 10)
# Body part 10: Confidence = 0.006824681535363197, Point = (43, 2)
# Body part 11: Confidence = 0.06405425816774368, Point = (26, 37)
# Body part 12: Confidence = 0.009357237257063389, Point = (26, 11)
# Body part 13: Confidence = 0.009243245236575603, Point = (45, 1)
# Body part 14: Confidence = 0.7640817165374756, Point = (24, 9)
# Body part 15: Confidence = 0.8041329383850098, Point = (25, 9)
# Body part 16: Confidence = 0.46290236711502075, Point = (23, 10)
# Body part 17: Confidence = 0.6541968584060669, Point = (27, 10)
# Body part 18: Confidence = 1.0044183731079102, Point = (44, 30)
# Body part 0: Confidence = 0.7525368928909302, Point = (25, 10)
# Body part 1: Confidence = 0.5616554021835327, Point = (26, 18)
# Body part 2: Confidence = 0.5343979597091675, Point = (22, 18)
# Body part 3: Confidence = 0.02975689060986042, Point = (21, 27)
# Body part 4: Confidence = 0.04153808206319809, Point = (24, 35)
# Body part 5: Confidence = 0.4746246933937073, Point = (29, 18)
# Body part 6: Confidence = 0.2049408107995987, Point = (31, 29)
# Body part 7: Confidence = 0.07750070095062256, Point = (25, 35)
# Body part 8: Confidence = 0.08314091712236404, Point = (24, 34)
# Body part 9: Confidence = 0.013064621016383171, Point = (23, 38)
# Body part 10: Confidence = 0.00668022595345974, Point = (43, 2)
# Body part 11: Confidence = 0.06322098523378372, Point = (27, 35)
# Body part 12: Confidence = 0.00752261420711875, Point = (24, 37)
# Body part 13: Confidence = 0.009239234030246735, Point = (45, 1)
# Body part 14: Confidence = 0.7366557121276855, Point = (24, 9)
# Body part 15: Confidence = 0.7790762186050415, Point = (25, 9)
# Body part 16: Confidence = 0.4581061899662018, Point = (23, 10)
# Body part 17: Confidence = 0.653784453868866, Point = (27, 10)
# Body part 18: Confidence = 1.0043898820877075, Point = (44, 30)
# Body part 0: Confidence = 0.755276083946228, Point = (25, 10)
# Body part 1: Confidence = 0.5277855396270752, Point = (26, 18)
# Body part 2: Confidence = 0.49489012360572815, Point = (22, 18)
# Body part 3: Confidence = 0.029067127034068108, Point = (21, 27)
# Body part 4: Confidence = 0.027218088507652283, Point = (24, 35)
# Body part 5: Confidence = 0.45905691385269165, Point = (29, 18)
# Body part 6: Confidence = 0.2246309071779251, Point = (31, 29)
# Body part 7: Confidence = 0.046973176300525665, Point = (29, 34)
# Body part 8: Confidence = 0.11054569482803345, Point = (24, 33)
# Body part 9: Confidence = 0.00864841602742672, Point = (26, 10)
# Body part 10: Confidence = 0.006849812343716621, Point = (43, 2)
# Body part 11: Confidence = 0.06264897435903549, Point = (27, 35)
# Body part 12: Confidence = 0.00988129060715437, Point = (26, 11)
# Body part 13: Confidence = 0.009477609768509865, Point = (45, 1)
# Body part 14: Confidence = 0.7289136648178101, Point = (24, 9)
# Body part 15: Confidence = 0.7699545621871948, Point = (25, 9)
# Body part 16: Confidence = 0.4357645511627197, Point = (23, 10)
# Body part 17: Confidence = 0.6444516181945801, Point = (27, 10)
# Body part 18: Confidence = 1.0040409564971924, Point = (44, 30)
# Body part 0: Confidence = 0.7415699362754822, Point = (25, 10)
# Body part 1: Confidence = 0.47794264554977417, Point = (26, 18)
# Body part 2: Confidence = 0.3993018865585327, Point = (22, 18)
# Body part 3: Confidence = 0.021690551191568375, Point = (21, 25)
# Body part 4: Confidence = 0.029918665066361427, Point = (24, 35)
# Body part 5: Confidence = 0.4555755853652954, Point = (29, 18)
# Body part 6: Confidence = 0.25737982988357544, Point = (31, 29)
# Body part 7: Confidence = 0.05970098078250885, Point = (28, 34)
# Body part 8: Confidence = 0.1159018725156784, Point = (24, 34)
# Body part 9: Confidence = 0.007745623588562012, Point = (26, 10)
# Body part 10: Confidence = 0.006916239857673645, Point = (43, 2)
# Body part 11: Confidence = 0.08528462797403336, Point = (27, 35)
# Body part 12: Confidence = 0.01144325453788042, Point = (26, 11)
# Body part 13: Confidence = 0.009655275382101536, Point = (45, 1)
# Body part 14: Confidence = 0.736295759677887, Point = (24, 9)
# Body part 15: Confidence = 0.7528373599052429, Point = (25, 9)
# Body part 16: Confidence = 0.3907123804092407, Point = (23, 10)
# Body part 17: Confidence = 0.6497278809547424, Point = (27, 10)
# Body part 18: Confidence = 1.0040242671966553, Point = (44, 30)
# Body part 0: Confidence = 0.7554727792739868, Point = (25, 10)
# Body part 1: Confidence = 0.5302128791809082, Point = (26, 18)
# Body part 2: Confidence = 0.4264809489250183, Point = (22, 18)
# Body part 3: Confidence = 0.05429408699274063, Point = (19, 27)
# Body part 4: Confidence = 0.04467449337244034, Point = (24, 35)
# Body part 5: Confidence = 0.4923502504825592, Point = (29, 18)
# Body part 6: Confidence = 0.32198482751846313, Point = (31, 29)
# Body part 7: Confidence = 0.10648990422487259, Point = (26, 35)
# Body part 8: Confidence = 0.1516270488500595, Point = (24, 34)
# Body part 9: Confidence = 0.008304139599204063, Point = (27, 10)
# Body part 10: Confidence = 0.006836520507931709, Point = (43, 2)
# Body part 11: Confidence = 0.10261328518390656, Point = (27, 35)
# Body part 12: Confidence = 0.011141150258481503, Point = (26, 11)
# Body part 13: Confidence = 0.009638920426368713, Point = (45, 1)
# Body part 14: Confidence = 0.7291004657745361, Point = (24, 9)
# Body part 15: Confidence = 0.7124623656272888, Point = (25, 9)
# Body part 16: Confidence = 0.4231123626232147, Point = (23, 10)
# Body part 17: Confidence = 0.6319755911827087, Point = (27, 10)
# Body part 18: Confidence = 1.0035295486450195, Point = (44, 30)
# Body part 0: Confidence = 0.7553837895393372, Point = (25, 10)
# Body part 1: Confidence = 0.5320685505867004, Point = (26, 18)
# Body part 2: Confidence = 0.42812108993530273, Point = (22, 18)
# Body part 3: Confidence = 0.07569584250450134, Point = (21, 25)
# Body part 4: Confidence = 0.033977851271629333, Point = (24, 35)
# Body part 5: Confidence = 0.5099496245384216, Point = (29, 18)
# Body part 6: Confidence = 0.3463417887687683, Point = (31, 29)
# Body part 7: Confidence = 0.07839829474687576, Point = (28, 34)
# Body part 8: Confidence = 0.14840371906757355, Point = (24, 34)
# Body part 9: Confidence = 0.013501597568392754, Point = (17, 23)
# Body part 10: Confidence = 0.008786223828792572, Point = (17, 25)
# Body part 11: Confidence = 0.11251920461654663, Point = (27, 35)
# Body part 12: Confidence = 0.009687172248959541, Point = (26, 11)
# Body part 13: Confidence = 0.009650791063904762, Point = (45, 1)
# Body part 14: Confidence = 0.7146170735359192, Point = (24, 9)
# Body part 15: Confidence = 0.7100033164024353, Point = (26, 9)
# Body part 16: Confidence = 0.412699431180954, Point = (23, 10)
# Body part 17: Confidence = 0.6408002376556396, Point = (27, 10)
# Body part 18: Confidence = 1.0039911270141602, Point = (44, 30)
# Body part 0: Confidence = 0.7570239901542664, Point = (25, 10)
# Body part 1: Confidence = 0.4635962247848511, Point = (25, 18)
# Body part 2: Confidence = 0.41539403796195984, Point = (22, 18)
# Body part 3: Confidence = 0.03418273478746414, Point = (19, 27)
# Body part 4: Confidence = 0.02705984376370907, Point = (24, 35)
# Body part 5: Confidence = 0.4874790906906128, Point = (29, 18)
# Body part 6: Confidence = 0.21185016632080078, Point = (31, 29)
# Body part 7: Confidence = 0.040507227182388306, Point = (29, 33)
# Body part 8: Confidence = 0.10522159934043884, Point = (24, 34)
# Body part 9: Confidence = 0.008489033207297325, Point = (27, 10)
# Body part 10: Confidence = 0.007511120289564133, Point = (24, 10)
# Body part 11: Confidence = 0.09960993379354477, Point = (26, 36)
# Body part 12: Confidence = 0.008635567501187325, Point = (26, 11)
# Body part 13: Confidence = 0.009651720523834229, Point = (45, 1)
# Body part 14: Confidence = 0.7119495868682861, Point = (24, 9)
# Body part 15: Confidence = 0.7322602868080139, Point = (26, 9)
# Body part 16: Confidence = 0.49284031987190247, Point = (23, 10)
# Body part 17: Confidence = 0.6375434994697571, Point = (27, 10)
# Body part 18: Confidence = 1.0037239789962769, Point = (44, 30)
# Body part 0: Confidence = 0.76612788438797, Point = (25, 10)
# Body part 1: Confidence = 0.5377964377403259, Point = (25, 18)
# Body part 2: Confidence = 0.39965808391571045, Point = (21, 18)
# Body part 3: Confidence = 0.02069186046719551, Point = (21, 23)
# Body part 4: Confidence = 0.03553277999162674, Point = (24, 35)
# Body part 5: Confidence = 0.5138136744499207, Point = (29, 18)
# Body part 6: Confidence = 0.16605177521705627, Point = (31, 28)
# Body part 7: Confidence = 0.0712190568447113, Point = (26, 35)
# Body part 8: Confidence = 0.12836672365665436, Point = (24, 34)
# Body part 9: Confidence = 0.02695516124367714, Point = (23, 45)
# Body part 10: Confidence = 0.011403782293200493, Point = (23, 45)
# Body part 11: Confidence = 0.1572275608778, Point = (26, 36)
# Body part 12: Confidence = 0.008931372314691544, Point = (26, 11)
# Body part 13: Confidence = 0.009651563130319118, Point = (45, 1)
# Body part 14: Confidence = 0.7397539615631104, Point = (24, 10)
# Body part 15: Confidence = 0.7582109570503235, Point = (26, 9)
# Body part 16: Confidence = 0.5073433518409729, Point = (23, 10)
# Body part 17: Confidence = 0.633736252784729, Point = (27, 10)
# Body part 18: Confidence = 1.0041873455047607, Point = (44, 30)
# Body part 0: Confidence = 0.7780866026878357, Point = (25, 10)
# Body part 1: Confidence = 0.5678626894950867, Point = (25, 18)
# Body part 2: Confidence = 0.38940203189849854, Point = (21, 18)
# Body part 3: Confidence = 0.04614684730768204, Point = (20, 23)
# Body part 4: Confidence = 0.03655688464641571, Point = (20, 20)
# Body part 5: Confidence = 0.5400998592376709, Point = (29, 18)
# Body part 6: Confidence = 0.13754352927207947, Point = (31, 28)
# Body part 7: Confidence = 0.02609141357243061, Point = (26, 35)
# Body part 8: Confidence = 0.1498054563999176, Point = (24, 34)
# Body part 9: Confidence = 0.024701222777366638, Point = (18, 23)
# Body part 10: Confidence = 0.0707601010799408, Point = (18, 27)
# Body part 11: Confidence = 0.15347588062286377, Point = (26, 36)
# Body part 12: Confidence = 0.017324861139059067, Point = (18, 22)
# Body part 13: Confidence = 0.04342355579137802, Point = (18, 27)
# Body part 14: Confidence = 0.7343141436576843, Point = (24, 10)
# Body part 15: Confidence = 0.7838345766067505, Point = (26, 9)
# Body part 16: Confidence = 0.5387955904006958, Point = (23, 10)
# Body part 17: Confidence = 0.644572913646698, Point = (27, 10)
# Body part 18: Confidence = 1.0037027597427368, Point = (44, 30)
# Body part 0: Confidence = 0.7844003438949585, Point = (25, 10)
# Body part 1: Confidence = 0.5958850979804993, Point = (26, 18)
# Body part 2: Confidence = 0.48647043108940125, Point = (22, 18)
# Body part 3: Confidence = 0.11966140568256378, Point = (18, 25)
# Body part 4: Confidence = 0.04542020708322525, Point = (19, 25)
# Body part 5: Confidence = 0.5552529692649841, Point = (29, 18)
# Body part 6: Confidence = 0.14314885437488556, Point = (31, 28)
# Body part 7: Confidence = 0.03170912712812424, Point = (26, 35)
# Body part 8: Confidence = 0.14144621789455414, Point = (24, 34)
# Body part 9: Confidence = 0.009609207510948181, Point = (27, 10)
# Body part 10: Confidence = 0.008592449128627777, Point = (24, 10)
# Body part 11: Confidence = 0.14925405383110046, Point = (26, 36)
# Body part 12: Confidence = 0.01078316941857338, Point = (20, 25)
# Body part 13: Confidence = 0.009670116007328033, Point = (45, 1)
# Body part 14: Confidence = 0.7415568828582764, Point = (24, 10)
# Body part 15: Confidence = 0.7815340161323547, Point = (26, 9)
# Body part 16: Confidence = 0.578339695930481, Point = (23, 11)
# Body part 17: Confidence = 0.6685453653335571, Point = (27, 10)
# Body part 18: Confidence = 1.00418221950531, Point = (44, 30)
# Body part 0: Confidence = 0.797994077205658, Point = (25, 10)
# Body part 1: Confidence = 0.6327278017997742, Point = (25, 18)
# Body part 2: Confidence = 0.563850462436676, Point = (22, 18)
# Body part 3: Confidence = 0.2193080484867096, Point = (18, 26)
# Body part 4: Confidence = 0.1276872158050537, Point = (18, 24)
# Body part 5: Confidence = 0.5541417002677917, Point = (29, 18)
# Body part 6: Confidence = 0.2557155191898346, Point = (31, 29)
# Body part 7: Confidence = 0.06307991594076157, Point = (28, 35)
# Body part 8: Confidence = 0.19439522922039032, Point = (23, 33)
# Body part 9: Confidence = 0.014947591349482536, Point = (28, 41)
# Body part 10: Confidence = 0.008426982909440994, Point = (24, 10)
# Body part 11: Confidence = 0.18753138184547424, Point = (26, 36)
# Body part 12: Confidence = 0.026043783873319626, Point = (26, 42)
# Body part 13: Confidence = 0.009662301279604435, Point = (45, 1)
# Body part 14: Confidence = 0.7333859801292419, Point = (24, 9)
# Body part 15: Confidence = 0.794543981552124, Point = (26, 9)
# Body part 16: Confidence = 0.5588861107826233, Point = (23, 11)
# Body part 17: Confidence = 0.6663914918899536, Point = (27, 10)
# Body part 18: Confidence = 1.004173994064331, Point = (44, 30)
# Body part 0: Confidence = 0.7930545806884766, Point = (25, 10)
# Body part 1: Confidence = 0.6068160533905029, Point = (26, 18)
# Body part 2: Confidence = 0.492299348115921, Point = (22, 18)
# Body part 3: Confidence = 0.08631198108196259, Point = (19, 26)
# Body part 4: Confidence = 0.05301467329263687, Point = (20, 19)
# Body part 5: Confidence = 0.5210703611373901, Point = (29, 18)
# Body part 6: Confidence = 0.30703508853912354, Point = (31, 29)
# Body part 7: Confidence = 0.12957113981246948, Point = (28, 35)
# Body part 8: Confidence = 0.1849052459001541, Point = (23, 33)
# Body part 9: Confidence = 0.01739457994699478, Point = (28, 41)
# Body part 10: Confidence = 0.02245546691119671, Point = (19, 28)
# Body part 11: Confidence = 0.16656380891799927, Point = (27, 35)
# Body part 12: Confidence = 0.016761619597673416, Point = (27, 42)
# Body part 13: Confidence = 0.01993003860116005, Point = (18, 27)
# Body part 14: Confidence = 0.7267628908157349, Point = (24, 9)
# Body part 15: Confidence = 0.7759063243865967, Point = (26, 9)
# Body part 16: Confidence = 0.5146481394767761, Point = (23, 11)
# Body part 17: Confidence = 0.6520019769668579, Point = (27, 10)
# Body part 18: Confidence = 1.004280686378479, Point = (44, 30)
# Body part 0: Confidence = 0.7964079976081848, Point = (25, 10)
# Body part 1: Confidence = 0.6476584076881409, Point = (25, 18)
# Body part 2: Confidence = 0.5580726861953735, Point = (21, 18)
# Body part 3: Confidence = 0.2618965804576874, Point = (18, 26)
# Body part 4: Confidence = 0.12314184755086899, Point = (19, 27)
# Body part 5: Confidence = 0.526617705821991, Point = (29, 18)
# Body part 6: Confidence = 0.2390558272600174, Point = (31, 29)
# Body part 7: Confidence = 0.075871042907238, Point = (27, 35)
# Body part 8: Confidence = 0.16771499812602997, Point = (23, 32)
# Body part 9: Confidence = 0.011555902659893036, Point = (23, 38)
# Body part 10: Confidence = 0.008490875363349915, Point = (24, 10)
# Body part 11: Confidence = 0.12035465985536575, Point = (26, 37)
# Body part 12: Confidence = 0.009715740568935871, Point = (26, 37)
# Body part 13: Confidence = 0.009708023630082607, Point = (45, 1)
# Body part 14: Confidence = 0.7356383800506592, Point = (24, 9)
# Body part 15: Confidence = 0.7875787019729614, Point = (26, 9)
# Body part 16: Confidence = 0.5873849391937256, Point = (23, 11)
# Body part 17: Confidence = 0.6704096794128418, Point = (27, 10)
# Body part 18: Confidence = 1.0043014287948608, Point = (44, 30)
# Body part 0: Confidence = 0.7985093593597412, Point = (25, 10)
# Body part 1: Confidence = 0.6233639717102051, Point = (26, 18)
# Body part 2: Confidence = 0.5668098330497742, Point = (22, 18)
# Body part 3: Confidence = 0.1762276142835617, Point = (19, 27)
# Body part 4: Confidence = 0.023660825565457344, Point = (25, 35)
# Body part 5: Confidence = 0.5318477153778076, Point = (29, 18)
# Body part 6: Confidence = 0.25566747784614563, Point = (31, 29)
# Body part 7: Confidence = 0.10207752883434296, Point = (28, 35)
# Body part 8: Confidence = 0.16049028933048248, Point = (24, 33)
# Body part 9: Confidence = 0.012576745823025703, Point = (27, 42)
# Body part 10: Confidence = 0.008412249386310577, Point = (25, 10)
# Body part 11: Confidence = 0.11007191240787506, Point = (27, 35)
# Body part 12: Confidence = 0.009854092262685299, Point = (26, 36)
# Body part 13: Confidence = 0.009632314555346966, Point = (45, 1)
# Body part 14: Confidence = 0.7251179218292236, Point = (24, 10)
# Body part 15: Confidence = 0.792797327041626, Point = (26, 9)
# Body part 16: Confidence = 0.6618090271949768, Point = (23, 11)
# Body part 17: Confidence = 0.6554625034332275, Point = (27, 10)
# Body part 18: Confidence = 1.004855990409851, Point = (44, 30)
# Body part 0: Confidence = 0.7884351015090942, Point = (25, 10)
# Body part 1: Confidence = 0.5878317952156067, Point = (26, 19)
# Body part 2: Confidence = 0.548859179019928, Point = (22, 18)
# Body part 3: Confidence = 0.09637530148029327, Point = (19, 27)
# Body part 4: Confidence = 0.014549698680639267, Point = (25, 35)
# Body part 5: Confidence = 0.4978150427341461, Point = (29, 18)
# Body part 6: Confidence = 0.27745959162712097, Point = (31, 29)
# Body part 7: Confidence = 0.1340610831975937, Point = (29, 34)
# Body part 8: Confidence = 0.18591004610061646, Point = (24, 33)
# Body part 9: Confidence = 0.014188561588525772, Point = (26, 42)
# Body part 10: Confidence = 0.008469641208648682, Point = (24, 10)
# Body part 11: Confidence = 0.15226279199123383, Point = (27, 34)
# Body part 12: Confidence = 0.012722274288535118, Point = (28, 35)
# Body part 13: Confidence = 0.009569896385073662, Point = (45, 1)
# Body part 14: Confidence = 0.7271792888641357, Point = (24, 10)
# Body part 15: Confidence = 0.7810701131820679, Point = (26, 9)
# Body part 16: Confidence = 0.6555646657943726, Point = (23, 11)
# Body part 17: Confidence = 0.6375592947006226, Point = (27, 10)
# Body part 18: Confidence = 1.0052118301391602, Point = (44, 30)
# Body part 0: Confidence = 0.7658810615539551, Point = (25, 10)
# Body part 1: Confidence = 0.6140918135643005, Point = (26, 19)
# Body part 2: Confidence = 0.5441741347312927, Point = (22, 18)
# Body part 3: Confidence = 0.31234097480773926, Point = (19, 27)
# Body part 4: Confidence = 0.13220110535621643, Point = (17, 24)
# Body part 5: Confidence = 0.5163942575454712, Point = (29, 18)
# Body part 6: Confidence = 0.316190242767334, Point = (31, 29)
# Body part 7: Confidence = 0.14869970083236694, Point = (29, 34)
# Body part 8: Confidence = 0.1837853491306305, Point = (24, 33)
# Body part 9: Confidence = 0.022463422268629074, Point = (24, 38)
# Body part 10: Confidence = 0.008032623678445816, Point = (24, 10)
# Body part 11: Confidence = 0.1399928480386734, Point = (27, 35)
# Body part 12: Confidence = 0.01403600350022316, Point = (26, 36)
# Body part 13: Confidence = 0.009561821818351746, Point = (45, 1)
# Body part 14: Confidence = 0.7514710426330566, Point = (24, 10)
# Body part 15: Confidence = 0.769760012626648, Point = (26, 9)
# Body part 16: Confidence = 0.659647524356842, Point = (23, 11)
# Body part 17: Confidence = 0.6549332141876221, Point = (27, 10)
# Body part 18: Confidence = 1.0055731534957886, Point = (44, 30)
# Body part 0: Confidence = 0.7572730779647827, Point = (25, 10)
# Body part 1: Confidence = 0.6332414746284485, Point = (26, 19)
# Body part 2: Confidence = 0.5322113633155823, Point = (21, 19)
# Body part 3: Confidence = 0.43721798062324524, Point = (19, 27)
# Body part 4: Confidence = 0.22560755908489227, Point = (17, 24)
# Body part 5: Confidence = 0.5081225633621216, Point = (29, 18)
# Body part 6: Confidence = 0.26743072271347046, Point = (31, 29)
# Body part 7: Confidence = 0.1259012073278427, Point = (28, 35)
# Body part 8: Confidence = 0.197912335395813, Point = (23, 33)
# Body part 9: Confidence = 0.02093692123889923, Point = (24, 38)
# Body part 10: Confidence = 0.00954708643257618, Point = (23, 45)
# Body part 11: Confidence = 0.16277334094047546, Point = (27, 35)
# Body part 12: Confidence = 0.013345081359148026, Point = (26, 36)
# Body part 13: Confidence = 0.009561536833643913, Point = (45, 1)
# Body part 14: Confidence = 0.7442813515663147, Point = (24, 10)
# Body part 15: Confidence = 0.7638170123100281, Point = (26, 9)
# Body part 16: Confidence = 0.6246053576469421, Point = (23, 11)
# Body part 17: Confidence = 0.6441131830215454, Point = (27, 10)
# Body part 18: Confidence = 1.0055866241455078, Point = (44, 30)
# Body part 0: Confidence = 0.7450026273727417, Point = (25, 10)
# Body part 1: Confidence = 0.6403358578681946, Point = (26, 19)
# Body part 2: Confidence = 0.5331624746322632, Point = (21, 19)
# Body part 3: Confidence = 0.24849940836429596, Point = (19, 27)
# Body part 4: Confidence = 0.09315215051174164, Point = (17, 25)
# Body part 5: Confidence = 0.5049061179161072, Point = (30, 18)
# Body part 6: Confidence = 0.27126356959342957, Point = (31, 29)
# Body part 7: Confidence = 0.19012510776519775, Point = (28, 35)
# Body part 8: Confidence = 0.18295256793498993, Point = (24, 34)
# Body part 9: Confidence = 0.03300304710865021, Point = (23, 45)
# Body part 10: Confidence = 0.01678071916103363, Point = (23, 45)
# Body part 11: Confidence = 0.19690865278244019, Point = (27, 36)
# Body part 12: Confidence = 0.010773741640150547, Point = (24, 45)
# Body part 13: Confidence = 0.01212280709296465, Point = (23, 45)
# Body part 14: Confidence = 0.7570446729660034, Point = (24, 10)
# Body part 15: Confidence = 0.7640182375907898, Point = (26, 9)
# Body part 16: Confidence = 0.6279199123382568, Point = (23, 11)
# Body part 17: Confidence = 0.633401095867157, Point = (27, 10)
# Body part 18: Confidence = 1.0038914680480957, Point = (44, 30)
# Body part 0: Confidence = 0.7451067566871643, Point = (25, 11)
# Body part 1: Confidence = 0.6591331958770752, Point = (26, 19)
# Body part 2: Confidence = 0.497854620218277, Point = (21, 19)
# Body part 3: Confidence = 0.23602047562599182, Point = (18, 27)
# Body part 4: Confidence = 0.05635867267847061, Point = (15, 24)
# Body part 5: Confidence = 0.5013113617897034, Point = (30, 19)
# Body part 6: Confidence = 0.34731751680374146, Point = (31, 29)
# Body part 7: Confidence = 0.21363791823387146, Point = (28, 35)
# Body part 8: Confidence = 0.14742502570152283, Point = (23, 34)
# Body part 9: Confidence = 0.014736050739884377, Point = (25, 9)
# Body part 10: Confidence = 0.011138727888464928, Point = (12, 20)
# Body part 11: Confidence = 0.19105470180511475, Point = (27, 36)
# Body part 12: Confidence = 0.011599398218095303, Point = (26, 37)
# Body part 13: Confidence = 0.012113720178604126, Point = (12, 20)
# Body part 14: Confidence = 0.7577171325683594, Point = (24, 10)
# Body part 15: Confidence = 0.7540668845176697, Point = (26, 9)
# Body part 16: Confidence = 0.6222206354141235, Point = (23, 11)
# Body part 17: Confidence = 0.6229016184806824, Point = (27, 10)
# Body part 18: Confidence = 1.0040791034698486, Point = (44, 30)
# Body part 0: Confidence = 0.7665320038795471, Point = (25, 11)
# Body part 1: Confidence = 0.6424142122268677, Point = (26, 19)
# Body part 2: Confidence = 0.48829397559165955, Point = (22, 19)
# Body part 3: Confidence = 0.09168007969856262, Point = (19, 27)
# Body part 4: Confidence = 0.017813334241509438, Point = (25, 35)
# Body part 5: Confidence = 0.49795109033584595, Point = (30, 18)
# Body part 6: Confidence = 0.394168496131897, Point = (31, 29)
# Body part 7: Confidence = 0.24493341147899628, Point = (28, 35)
# Body part 8: Confidence = 0.16127754747867584, Point = (23, 34)
# Body part 9: Confidence = 0.02281828224658966, Point = (23, 45)
# Body part 10: Confidence = 0.01221044547855854, Point = (23, 45)
# Body part 11: Confidence = 0.21432046592235565, Point = (27, 36)
# Body part 12: Confidence = 0.013914410024881363, Point = (27, 42)
# Body part 13: Confidence = 0.008931739255785942, Point = (45, 2)
# Body part 14: Confidence = 0.7676869630813599, Point = (24, 10)
# Body part 15: Confidence = 0.7524951696395874, Point = (26, 9)
# Body part 16: Confidence = 0.632912814617157, Point = (23, 11)
# Body part 17: Confidence = 0.6207877993583679, Point = (27, 10)
# Body part 18: Confidence = 1.0038032531738281, Point = (44, 30)
# Body part 0: Confidence = 0.7430739402770996, Point = (25, 10)
# Body part 1: Confidence = 0.607836127281189, Point = (26, 19)
# Body part 2: Confidence = 0.44236645102500916, Point = (22, 19)
# Body part 3: Confidence = 0.09886825084686279, Point = (19, 28)
# Body part 4: Confidence = 0.0185240525752306, Point = (25, 35)
# Body part 5: Confidence = 0.47861939668655396, Point = (29, 19)
# Body part 6: Confidence = 0.38898056745529175, Point = (31, 29)
# Body part 7: Confidence = 0.2480381280183792, Point = (28, 35)
# Body part 8: Confidence = 0.16836363077163696, Point = (23, 34)
# Body part 9: Confidence = 0.019254913553595543, Point = (23, 45)
# Body part 10: Confidence = 0.009406078606843948, Point = (23, 45)
# Body part 11: Confidence = 0.23149879276752472, Point = (27, 36)
# Body part 12: Confidence = 0.013417035341262817, Point = (27, 42)
# Body part 13: Confidence = 0.008653601631522179, Point = (45, 1)
# Body part 14: Confidence = 0.7422385811805725, Point = (24, 10)
# Body part 15: Confidence = 0.7499028444290161, Point = (26, 9)
# Body part 16: Confidence = 0.5824177265167236, Point = (23, 11)
# Body part 17: Confidence = 0.6271291375160217, Point = (27, 10)
# Body part 18: Confidence = 1.004273772239685, Point = (43, 44)
# Body part 0: Confidence = 0.755138635635376, Point = (25, 10)
# Body part 1: Confidence = 0.5863988399505615, Point = (26, 19)
# Body part 2: Confidence = 0.4286145865917206, Point = (21, 20)
# Body part 3: Confidence = 0.02353440225124359, Point = (18, 28)
# Body part 4: Confidence = 0.01738281361758709, Point = (24, 35)
# Body part 5: Confidence = 0.47542503476142883, Point = (29, 19)
# Body part 6: Confidence = 0.38466939330101013, Point = (31, 29)
# Body part 7: Confidence = 0.24271060526371002, Point = (28, 35)
# Body part 8: Confidence = 0.16506001353263855, Point = (23, 34)
# Body part 9: Confidence = 0.016674932092428207, Point = (23, 45)
# Body part 10: Confidence = 0.009060382843017578, Point = (10, 32)
# Body part 11: Confidence = 0.2492212951183319, Point = (27, 36)
# Body part 12: Confidence = 0.016087820753455162, Point = (27, 42)
# Body part 13: Confidence = 0.009092288091778755, Point = (10, 32)
# Body part 14: Confidence = 0.7404897212982178, Point = (24, 10)
# Body part 15: Confidence = 0.7491579651832581, Point = (26, 9)
# Body part 16: Confidence = 0.5729584693908691, Point = (23, 11)
# Body part 17: Confidence = 0.6306433081626892, Point = (27, 10)
# Body part 18: Confidence = 1.0042304992675781, Point = (43, 44)
# Body part 0: Confidence = 0.7784912586212158, Point = (25, 10)
# Body part 1: Confidence = 0.6486119031906128, Point = (26, 19)
# Body part 2: Confidence = 0.4275471568107605, Point = (21, 19)
# Body part 3: Confidence = 0.10508047044277191, Point = (16, 30)
# Body part 4: Confidence = 0.02741094119846821, Point = (13, 33)
# Body part 5: Confidence = 0.5041543245315552, Point = (29, 19)
# Body part 6: Confidence = 0.4205034375190735, Point = (31, 29)
# Body part 7: Confidence = 0.25357893109321594, Point = (28, 35)
# Body part 8: Confidence = 0.13955751061439514, Point = (23, 35)
# Body part 9: Confidence = 0.017001744359731674, Point = (23, 45)
# Body part 10: Confidence = 0.008020691573619843, Point = (43, 2)
# Body part 11: Confidence = 0.23494568467140198, Point = (27, 36)
# Body part 12: Confidence = 0.011802091263234615, Point = (26, 37)
# Body part 13: Confidence = 0.009151339530944824, Point = (45, 1)
# Body part 14: Confidence = 0.7266370058059692, Point = (24, 10)
# Body part 15: Confidence = 0.7679470777511597, Point = (26, 9)
# Body part 16: Confidence = 0.5707229971885681, Point = (23, 11)
# Body part 17: Confidence = 0.6424198746681213, Point = (27, 10)
# Body part 18: Confidence = 1.0045664310455322, Point = (44, 30)
# Body part 0: Confidence = 0.7858286499977112, Point = (25, 10)
# Body part 1: Confidence = 0.643843412399292, Point = (26, 19)
# Body part 2: Confidence = 0.5344160795211792, Point = (22, 18)
# Body part 3: Confidence = 0.11814665794372559, Point = (18, 28)
# Body part 4: Confidence = 0.026228755712509155, Point = (24, 35)
# Body part 5: Confidence = 0.48907843232154846, Point = (29, 18)
# Body part 6: Confidence = 0.4030838906764984, Point = (31, 29)
# Body part 7: Confidence = 0.2638198733329773, Point = (28, 35)
# Body part 8: Confidence = 0.12979534268379211, Point = (23, 35)
# Body part 9: Confidence = 0.01668570004403591, Point = (23, 45)
# Body part 10: Confidence = 0.008001705631613731, Point = (24, 10)
# Body part 11: Confidence = 0.24736833572387695, Point = (27, 36)
# Body part 12: Confidence = 0.012109678238630295, Point = (27, 42)
# Body part 13: Confidence = 0.009412281215190887, Point = (45, 1)
# Body part 14: Confidence = 0.71809983253479, Point = (24, 10)
# Body part 15: Confidence = 0.7793481945991516, Point = (26, 9)
# Body part 16: Confidence = 0.5768293142318726, Point = (23, 11)
# Body part 17: Confidence = 0.6366472244262695, Point = (27, 10)
# Body part 18: Confidence = 1.0045373439788818, Point = (43, 44)
# Body part 0: Confidence = 0.7839735746383667, Point = (25, 10)
# Body part 1: Confidence = 0.6216250658035278, Point = (26, 19)
# Body part 2: Confidence = 0.5731183290481567, Point = (22, 18)
# Body part 3: Confidence = 0.04036084562540054, Point = (18, 30)
# Body part 4: Confidence = 0.01872452162206173, Point = (24, 35)
# Body part 5: Confidence = 0.5041574239730835, Point = (29, 18)
# Body part 6: Confidence = 0.38261595368385315, Point = (31, 29)
# Body part 7: Confidence = 0.21159076690673828, Point = (28, 35)
# Body part 8: Confidence = 0.10468587279319763, Point = (23, 36)
# Body part 9: Confidence = 0.010429369285702705, Point = (27, 10)
# Body part 10: Confidence = 0.008174851536750793, Point = (24, 10)
# Body part 11: Confidence = 0.19678862392902374, Point = (27, 36)
# Body part 12: Confidence = 0.010722370818257332, Point = (26, 37)
# Body part 13: Confidence = 0.009242964908480644, Point = (45, 1)
# Body part 14: Confidence = 0.6919361352920532, Point = (24, 9)
# Body part 15: Confidence = 0.7720640897750854, Point = (26, 9)
# Body part 16: Confidence = 0.5267353653907776, Point = (23, 11)
# Body part 17: Confidence = 0.6369562745094299, Point = (27, 10)
# Body part 18: Confidence = 1.0034563541412354, Point = (44, 30)
# Body part 0: Confidence = 0.7429678440093994, Point = (25, 10)
# Body part 1: Confidence = 0.5685975551605225, Point = (26, 19)
# Body part 2: Confidence = 0.5862913131713867, Point = (22, 19)
# Body part 3: Confidence = 0.12486642599105835, Point = (19, 28)
# Body part 4: Confidence = 0.017627838999032974, Point = (24, 35)
# Body part 5: Confidence = 0.4912477731704712, Point = (29, 18)
# Body part 6: Confidence = 0.3720676898956299, Point = (31, 29)
# Body part 7: Confidence = 0.1944129765033722, Point = (28, 35)
# Body part 8: Confidence = 0.11055050790309906, Point = (23, 37)
# Body part 9: Confidence = 0.010529235005378723, Point = (27, 10)
# Body part 10: Confidence = 0.008128423243761063, Point = (43, 2)
# Body part 11: Confidence = 0.18828421831130981, Point = (27, 37)
# Body part 12: Confidence = 0.012049822136759758, Point = (27, 42)
# Body part 13: Confidence = 0.009243790060281754, Point = (45, 1)
# Body part 14: Confidence = 0.6678450703620911, Point = (24, 9)
# Body part 15: Confidence = 0.7375765442848206, Point = (26, 9)
# Body part 16: Confidence = 0.4935119152069092, Point = (23, 10)
# Body part 17: Confidence = 0.6101490259170532, Point = (27, 10)
# Body part 18: Confidence = 1.0036123991012573, Point = (44, 30)
# Body part 0: Confidence = 0.7404696345329285, Point = (25, 10)
# Body part 1: Confidence = 0.5302948355674744, Point = (25, 19)
# Body part 2: Confidence = 0.5579290390014648, Point = (22, 19)
# Body part 3: Confidence = 0.055455297231674194, Point = (19, 29)
# Body part 4: Confidence = 0.019070275127887726, Point = (24, 35)
# Body part 5: Confidence = 0.4674455523490906, Point = (29, 18)
# Body part 6: Confidence = 0.24817003309726715, Point = (31, 29)
# Body part 7: Confidence = 0.12417198717594147, Point = (28, 35)
# Body part 8: Confidence = 0.10523462295532227, Point = (23, 37)
# Body part 9: Confidence = 0.010333891957998276, Point = (27, 10)
# Body part 10: Confidence = 0.008129965513944626, Point = (43, 2)
# Body part 11: Confidence = 0.1713157296180725, Point = (27, 37)
# Body part 12: Confidence = 0.013573076575994492, Point = (27, 42)
# Body part 13: Confidence = 0.009243570268154144, Point = (45, 1)
# Body part 14: Confidence = 0.6945756077766418, Point = (24, 9)
# Body part 15: Confidence = 0.7369799613952637, Point = (26, 9)
# Body part 16: Confidence = 0.49322783946990967, Point = (23, 10)
# Body part 17: Confidence = 0.6253260374069214, Point = (27, 10)
# Body part 18: Confidence = 1.0040522813796997, Point = (44, 30)
# Body part 0: Confidence = 0.7472747564315796, Point = (25, 10)
# Body part 1: Confidence = 0.6199812293052673, Point = (25, 19)
# Body part 2: Confidence = 0.619891881942749, Point = (22, 19)
# Body part 3: Confidence = 0.37799879908561707, Point = (19, 36)
# Body part 4: Confidence = 0.19972486793994904, Point = (19, 42)
# Body part 5: Confidence = 0.5454279184341431, Point = (29, 18)
# Body part 6: Confidence = 0.31388992071151733, Point = (30, 29)
# Body part 7: Confidence = 0.16855549812316895, Point = (28, 35)
# Body part 8: Confidence = 0.11563180387020111, Point = (23, 39)
# Body part 9: Confidence = 0.02215372398495674, Point = (19, 44)
# Body part 10: Confidence = 0.02337609976530075, Point = (19, 44)
# Body part 11: Confidence = 0.1731320023536682, Point = (26, 38)
# Body part 12: Confidence = 0.023656059056520462, Point = (27, 42)
# Body part 13: Confidence = 0.009650344960391521, Point = (45, 1)
# Body part 14: Confidence = 0.7070503234863281, Point = (24, 9)
# Body part 15: Confidence = 0.7533496618270874, Point = (26, 9)
# Body part 16: Confidence = 0.5391772985458374, Point = (23, 11)
# Body part 17: Confidence = 0.6866798996925354, Point = (27, 10)
# Body part 18: Confidence = 1.0040630102157593, Point = (44, 30)
# Body part 0: Confidence = 0.7174074053764343, Point = (25, 10)
# Body part 1: Confidence = 0.638683557510376, Point = (25, 19)
# Body part 2: Confidence = 0.5954551100730896, Point = (22, 19)
# Body part 3: Confidence = 0.05560847371816635, Point = (21, 29)
# Body part 4: Confidence = 0.013594023883342743, Point = (24, 35)
# Body part 5: Confidence = 0.6038131713867188, Point = (29, 18)
# Body part 6: Confidence = 0.3669898808002472, Point = (30, 29)
# Body part 7: Confidence = 0.19660045206546783, Point = (28, 35)
# Body part 8: Confidence = 0.10959254205226898, Point = (24, 33)
# Body part 9: Confidence = 0.009552368894219398, Point = (26, 10)
# Body part 10: Confidence = 0.007922964170575142, Point = (43, 2)
# Body part 11: Confidence = 0.11792074888944626, Point = (27, 37)
# Body part 12: Confidence = 0.009892089292407036, Point = (27, 42)
# Body part 13: Confidence = 0.009691070765256882, Point = (45, 1)
# Body part 14: Confidence = 0.6841371059417725, Point = (24, 10)
# Body part 15: Confidence = 0.729453980922699, Point = (25, 9)
# Body part 16: Confidence = 0.45331546664237976, Point = (23, 11)
# Body part 17: Confidence = 0.6882008910179138, Point = (27, 10)
# Body part 18: Confidence = 1.0039690732955933, Point = (44, 30)
# Body part 0: Confidence = 0.672663152217865, Point = (24, 10)
# Body part 1: Confidence = 0.6156757473945618, Point = (25, 18)
# Body part 2: Confidence = 0.6202636957168579, Point = (22, 19)
# Body part 3: Confidence = 0.06657053530216217, Point = (21, 28)
# Body part 4: Confidence = 0.009035984985530376, Point = (45, 2)
# Body part 5: Confidence = 0.6078294515609741, Point = (29, 18)
# Body part 6: Confidence = 0.26763245463371277, Point = (30, 28)
# Body part 7: Confidence = 0.09030425548553467, Point = (29, 33)
# Body part 8: Confidence = 0.10605019330978394, Point = (24, 33)
# Body part 9: Confidence = 0.009935110807418823, Point = (26, 10)
# Body part 10: Confidence = 0.0077268388122320175, Point = (43, 2)
# Body part 11: Confidence = 0.10137498378753662, Point = (27, 36)
# Body part 12: Confidence = 0.009529798291623592, Point = (28, 35)
# Body part 13: Confidence = 0.009268976747989655, Point = (45, 1)
# Body part 14: Confidence = 0.6521320939064026, Point = (24, 9)
# Body part 15: Confidence = 0.7585546374320984, Point = (25, 9)
# Body part 16: Confidence = 0.3291626572608948, Point = (23, 10)
# Body part 17: Confidence = 0.6789404153823853, Point = (27, 10)
# Body part 18: Confidence = 1.0039762258529663, Point = (44, 30)
# Body part 0: Confidence = 0.6652432680130005, Point = (24, 11)
# Body part 1: Confidence = 0.6233879327774048, Point = (25, 18)
# Body part 2: Confidence = 0.6081733703613281, Point = (22, 19)
# Body part 3: Confidence = 0.07777312397956848, Point = (21, 28)
# Body part 4: Confidence = 0.01462014764547348, Point = (24, 35)
# Body part 5: Confidence = 0.6172517538070679, Point = (29, 18)
# Body part 6: Confidence = 0.22233699262142181, Point = (30, 29)
# Body part 7: Confidence = 0.0732734277844429, Point = (29, 33)
# Body part 8: Confidence = 0.16263122856616974, Point = (24, 34)
# Body part 9: Confidence = 0.009222103282809258, Point = (26, 10)
# Body part 10: Confidence = 0.007732383906841278, Point = (43, 2)
# Body part 11: Confidence = 0.14046864211559296, Point = (27, 36)
# Body part 12: Confidence = 0.013537496328353882, Point = (27, 42)
# Body part 13: Confidence = 0.009268207475543022, Point = (45, 1)
# Body part 14: Confidence = 0.6393892765045166, Point = (24, 10)
# Body part 15: Confidence = 0.7380471229553223, Point = (25, 9)
# Body part 16: Confidence = 0.45247116684913635, Point = (23, 10)
# Body part 17: Confidence = 0.6581123471260071, Point = (27, 10)
# Body part 18: Confidence = 1.0042601823806763, Point = (44, 30)
# Body part 0: Confidence = 0.6917994022369385, Point = (24, 10)
# Body part 1: Confidence = 0.5972994565963745, Point = (25, 18)
# Body part 2: Confidence = 0.6111438870429993, Point = (22, 19)
# Body part 3: Confidence = 0.06036503612995148, Point = (22, 26)
# Body part 4: Confidence = 0.013187562115490437, Point = (24, 35)
# Body part 5: Confidence = 0.5804581642150879, Point = (29, 18)
# Body part 6: Confidence = 0.3465319275856018, Point = (30, 29)
# Body part 7: Confidence = 0.14855648577213287, Point = (29, 33)
# Body part 8: Confidence = 0.1437206119298935, Point = (24, 33)
# Body part 9: Confidence = 0.013342179358005524, Point = (23, 42)
# Body part 10: Confidence = 0.010370435193181038, Point = (26, 43)
# Body part 11: Confidence = 0.15212255716323853, Point = (27, 35)
# Body part 12: Confidence = 0.023984137922525406, Point = (27, 42)
# Body part 13: Confidence = 0.009270206093788147, Point = (45, 1)
# Body part 14: Confidence = 0.6361345648765564, Point = (24, 9)
# Body part 15: Confidence = 0.7796100974082947, Point = (25, 9)
# Body part 16: Confidence = 0.48755913972854614, Point = (22, 10)
# Body part 17: Confidence = 0.7142015099525452, Point = (27, 10)
# Body part 18: Confidence = 1.0041521787643433, Point = (44, 30)
# Body part 0: Confidence = 0.681117594242096, Point = (24, 10)
# Body part 1: Confidence = 0.5746819972991943, Point = (25, 19)
# Body part 2: Confidence = 0.6184544563293457, Point = (22, 19)
# Body part 3: Confidence = 0.08854895830154419, Point = (22, 27)
# Body part 4: Confidence = 0.02377304621040821, Point = (24, 35)
# Body part 5: Confidence = 0.5447818040847778, Point = (29, 18)
# Body part 6: Confidence = 0.3295910954475403, Point = (30, 29)
# Body part 7: Confidence = 0.14093017578125, Point = (29, 34)
# Body part 8: Confidence = 0.1533716320991516, Point = (24, 34)
# Body part 9: Confidence = 0.01699312962591648, Point = (23, 42)
# Body part 10: Confidence = 0.010400161147117615, Point = (26, 43)
# Body part 11: Confidence = 0.142252117395401, Point = (26, 36)
# Body part 12: Confidence = 0.01426851935684681, Point = (27, 42)
# Body part 13: Confidence = 0.009631315246224403, Point = (45, 1)
# Body part 14: Confidence = 0.6591913104057312, Point = (24, 9)
# Body part 15: Confidence = 0.769237756729126, Point = (25, 10)
# Body part 16: Confidence = 0.45644110441207886, Point = (22, 10)
# Body part 17: Confidence = 0.6755754947662354, Point = (27, 10)
# Body part 18: Confidence = 1.0042202472686768, Point = (44, 30)
# Body part 0: Confidence = 0.6860669851303101, Point = (24, 10)
# Body part 1: Confidence = 0.5405732989311218, Point = (25, 19)
# Body part 2: Confidence = 0.5913260579109192, Point = (22, 19)
# Body part 3: Confidence = 0.06533289700746536, Point = (22, 28)
# Body part 4: Confidence = 0.0277267899364233, Point = (24, 35)
# Body part 5: Confidence = 0.486035019159317, Point = (29, 18)
# Body part 6: Confidence = 0.25654277205467224, Point = (31, 29)
# Body part 7: Confidence = 0.07866434752941132, Point = (29, 34)
# Body part 8: Confidence = 0.1585691124200821, Point = (24, 34)
# Body part 9: Confidence = 0.030829746276140213, Point = (23, 45)
# Body part 10: Confidence = 0.014735464006662369, Point = (23, 45)
# Body part 11: Confidence = 0.16465282440185547, Point = (26, 36)
# Body part 12: Confidence = 0.011254068464040756, Point = (27, 42)
# Body part 13: Confidence = 0.009641979821026325, Point = (45, 1)
# Body part 14: Confidence = 0.626960039138794, Point = (23, 9)
# Body part 15: Confidence = 0.7744922637939453, Point = (25, 10)
# Body part 16: Confidence = 0.40921327471733093, Point = (22, 10)
# Body part 17: Confidence = 0.6410695314407349, Point = (27, 10)
# Body part 18: Confidence = 1.0039130449295044, Point = (44, 30)
# Body part 0: Confidence = 0.707932710647583, Point = (24, 10)
# Body part 1: Confidence = 0.5555256605148315, Point = (25, 19)
# Body part 2: Confidence = 0.6059370040893555, Point = (22, 19)
# Body part 3: Confidence = 0.05711724981665611, Point = (22, 29)
# Body part 4: Confidence = 0.052423544228076935, Point = (24, 35)
# Body part 5: Confidence = 0.4753718674182892, Point = (29, 18)
# Body part 6: Confidence = 0.5327874422073364, Point = (31, 29)
# Body part 7: Confidence = 0.12337750196456909, Point = (28, 35)
# Body part 8: Confidence = 0.09485958516597748, Point = (24, 34)
# ...
# Body part 4: Confidence = 0.06525831669569016, Point = (24, 35)
# Body part 5: Confidence = 0.4098566174507141, Point = (29, 18)
# Body part 6: Confidence = 0.4372771382331848, Point = (31, 29)
# Body part 7: Confidence = 0.19475936889648438, Point = (27, 35)
# Body part 8: Confidence = 0.10514773428440094, Point = (23, 36)
# Body part 9: Confidence = 0.018427852541208267, Point = (23, 45)
# Body part 10: Confidence = 0.008802337571978569, Point = (43, 2)
# Body part 11: Confidence = 0.18558233976364136, Point = (26, 37)
# Body part 12: Confidence = 0.008365810848772526, Point = (22, 34)
# Body part 13: Confidence = 0.009377049282193184, Point = (45, 1)
# Body part 14: Confidence = 0.6688617467880249, Point = (23, 10)
# Body part 15: Confidence = 0.7706996202468872, Point = (25, 9)
# Body part 16: Confidence = 0.4390392601490021, Point = (22, 10)
# Body part 17: Confidence = 0.6547651886940002, Point = (26, 10)
# Body part 18: Confidence = 1.0035417079925537, Point = (44, 30)
# Body part 0: Confidence = 0.7013800144195557, Point = (24, 10)
# Body part 1: Confidence = 0.5303517580032349, Point = (26, 19)
# Body part 2: Confidence = 0.603654146194458, Point = (22, 19)
# Body part 3: Confidence = 0.07462906837463379, Point = (22, 29)
# Body part 4: Confidence = 0.09542816877365112, Point = (24, 35)
# Body part 5: Confidence = 0.4042793810367584, Point = (29, 19)
# Body part 6: Confidence = 0.3822166323661804, Point = (31, 29)
# Body part 7: Confidence = 0.31941065192222595, Point = (25, 36)
# Body part 8: Confidence = 0.16108357906341553, Point = (23, 37)
# Body part 9: Confidence = 0.040814075618982315, Point = (23, 45)
# Body part 10: Confidence = 0.021242793649435043, Point = (23, 45)
# Body part 11: Confidence = 0.2443925440311432, Point = (26, 38)
# Body part 12: Confidence = 0.00984934438019991, Point = (23, 45)
# Body part 13: Confidence = 0.013538517989218235, Point = (23, 45)
# Body part 14: Confidence = 0.6771154403686523, Point = (23, 10)
# Body part 15: Confidence = 0.773028552532196, Point = (25, 9)
# Body part 16: Confidence = 0.4436882734298706, Point = (22, 10)
# Body part 17: Confidence = 0.6468832492828369, Point = (26, 10)
# Body part 18: Confidence = 1.003538727760315, Point = (44, 30)
# Body part 0: Confidence = 0.6954225897789001, Point = (24, 10)
# Body part 1: Confidence = 0.5371487140655518, Point = (26, 19)
# Body part 2: Confidence = 0.6036516427993774, Point = (22, 19)
# Body part 3: Confidence = 0.09794825315475464, Point = (22, 29)
# Body part 4: Confidence = 0.09500955790281296, Point = (24, 35)
# Body part 5: Confidence = 0.3886823356151581, Point = (29, 19)
# Body part 6: Confidence = 0.3802890479564667, Point = (31, 29)
# Body part 7: Confidence = 0.21643906831741333, Point = (25, 35)
# Body part 8: Confidence = 0.10786010324954987, Point = (23, 34)
# Body part 9: Confidence = 0.032915711402893066, Point = (23, 38)
# Body part 10: Confidence = 0.008508950471878052, Point = (43, 2)
# Body part 11: Confidence = 0.1366933137178421, Point = (26, 37)
# Body part 12: Confidence = 0.014879798516631126, Point = (23, 38)
# Body part 13: Confidence = 0.00951264426112175, Point = (45, 1)
# Body part 14: Confidence = 0.6724920272827148, Point = (23, 10)
# Body part 15: Confidence = 0.7661741971969604, Point = (25, 10)
# Body part 16: Confidence = 0.46552738547325134, Point = (22, 10)
# Body part 17: Confidence = 0.6337425112724304, Point = (26, 10)
# Body part 18: Confidence = 1.0035470724105835, Point = (44, 30)
# Body part 0: Confidence = 0.6887686252593994, Point = (24, 10)
# Body part 1: Confidence = 0.545859694480896, Point = (26, 19)
# Body part 2: Confidence = 0.61655193567276, Point = (22, 19)
# Body part 3: Confidence = 0.08847448229789734, Point = (22, 29)
# Body part 4: Confidence = 0.077193483710289, Point = (24, 35)
# Body part 5: Confidence = 0.3465188145637512, Point = (29, 19)
# Body part 6: Confidence = 0.10804963111877441, Point = (30, 29)
# Body part 7: Confidence = 0.12630435824394226, Point = (25, 35)
# Body part 8: Confidence = 0.09772241115570068, Point = (23, 34)
# Body part 9: Confidence = 0.023616451770067215, Point = (23, 38)
# Body part 10: Confidence = 0.008505009114742279, Point = (43, 2)
# Body part 11: Confidence = 0.11701203137636185, Point = (26, 37)
# Body part 12: Confidence = 0.009912584908306599, Point = (23, 38)
# Body part 13: Confidence = 0.009512672200798988, Point = (45, 1)
# Body part 14: Confidence = 0.6603204607963562, Point = (23, 10)
# Body part 15: Confidence = 0.7490166425704956, Point = (25, 10)
# Body part 16: Confidence = 0.44687771797180176, Point = (22, 10)
# Body part 17: Confidence = 0.6288303732872009, Point = (26, 10)
# Body part 18: Confidence = 1.0035537481307983, Point = (44, 30)
# Body part 0: Confidence = 0.6951144337654114, Point = (24, 10)
# Body part 1: Confidence = 0.5410786867141724, Point = (26, 19)
# Body part 2: Confidence = 0.6190646290779114, Point = (22, 19)
# Body part 3: Confidence = 0.09649215638637543, Point = (22, 29)
# Body part 4: Confidence = 0.0679776594042778, Point = (24, 35)
# Body part 5: Confidence = 0.36575010418891907, Point = (29, 19)
# Body part 6: Confidence = 0.1229085773229599, Point = (30, 29)
# Body part 7: Confidence = 0.1036500334739685, Point = (25, 35)
# Body part 8: Confidence = 0.08120004832744598, Point = (23, 33)
# Body part 9: Confidence = 0.022751402109861374, Point = (23, 38)
# Body part 10: Confidence = 0.008300920948386192, Point = (43, 2)
# Body part 11: Confidence = 0.08012135326862335, Point = (26, 36)
# Body part 12: Confidence = 0.010058964602649212, Point = (28, 39)
# Body part 13: Confidence = 0.009520407766103745, Point = (45, 1)
# Body part 14: Confidence = 0.6693083047866821, Point = (23, 10)
# Body part 15: Confidence = 0.7589207887649536, Point = (25, 10)
# Body part 16: Confidence = 0.4495759606361389, Point = (22, 10)
# Body part 17: Confidence = 0.6321218013763428, Point = (26, 10)
# Body part 18: Confidence = 1.0032716989517212, Point = (44, 30)
# Body part 0: Confidence = 0.6952248215675354, Point = (24, 10)
# Body part 1: Confidence = 0.5430956482887268, Point = (26, 19)
# Body part 2: Confidence = 0.6155527234077454, Point = (22, 19)
# Body part 3: Confidence = 0.1081458032131195, Point = (22, 29)
# Body part 4: Confidence = 0.06708510965108871, Point = (24, 35)
# Body part 5: Confidence = 0.3751614987850189, Point = (29, 19)
# Body part 6: Confidence = 0.1545010656118393, Point = (30, 29)
# Body part 7: Confidence = 0.14004141092300415, Point = (25, 35)
# Body part 8: Confidence = 0.10088874399662018, Point = (23, 33)
# Body part 9: Confidence = 0.023885775357484818, Point = (23, 38)
# Body part 10: Confidence = 0.008300751447677612, Point = (43, 2)
# Body part 11: Confidence = 0.0895749181509018, Point = (26, 36)
# Body part 12: Confidence = 0.01047446671873331, Point = (23, 37)
# Body part 13: Confidence = 0.009519865736365318, Point = (45, 1)
# Body part 14: Confidence = 0.6633588671684265, Point = (23, 10)
# Body part 15: Confidence = 0.7621262073516846, Point = (25, 10)
# Body part 16: Confidence = 0.4498426914215088, Point = (22, 10)
# Body part 17: Confidence = 0.6328575015068054, Point = (26, 10)
# Body part 18: Confidence = 1.0035343170166016, Point = (44, 30)
# Body part 0: Confidence = 0.7084618210792542, Point = (24, 10)
# Body part 1: Confidence = 0.562282145023346, Point = (26, 19)
# Body part 2: Confidence = 0.6304277777671814, Point = (22, 19)
# Body part 3: Confidence = 0.09934847056865692, Point = (22, 29)
# Body part 4: Confidence = 0.06947631388902664, Point = (24, 35)
# Body part 5: Confidence = 0.41553834080696106, Point = (29, 18)
# Body part 6: Confidence = 0.18927887082099915, Point = (30, 29)
# Body part 7: Confidence = 0.20208503305912018, Point = (25, 35)
# Body part 8: Confidence = 0.08546815812587738, Point = (23, 33)
# Body part 9: Confidence = 0.021028924733400345, Point = (23, 38)
# Body part 10: Confidence = 0.008446872234344482, Point = (43, 2)
# Body part 11: Confidence = 0.09314319491386414, Point = (26, 37)
# Body part 12: Confidence = 0.01140269823372364, Point = (23, 37)
# Body part 13: Confidence = 0.009501202031970024, Point = (45, 1)
# Body part 14: Confidence = 0.6904457211494446, Point = (23, 10)
# Body part 15: Confidence = 0.7914588451385498, Point = (25, 10)
# Body part 16: Confidence = 0.5099760293960571, Point = (22, 10)
# Body part 17: Confidence = 0.6501758098602295, Point = (26, 10)
# Body part 18: Confidence = 1.0035419464111328, Point = (44, 30)
# Body part 0: Confidence = 0.7084841132164001, Point = (24, 11)
# Body part 1: Confidence = 0.5747235417366028, Point = (25, 19)
# Body part 2: Confidence = 0.6369250416755676, Point = (22, 19)
# Body part 3: Confidence = 0.10124707221984863, Point = (22, 29)
# Body part 4: Confidence = 0.06396874040365219, Point = (24, 35)
# Body part 5: Confidence = 0.4473598599433899, Point = (29, 18)
# Body part 6: Confidence = 0.2656080722808838, Point = (30, 29)
# Body part 7: Confidence = 0.20729222893714905, Point = (25, 35)
# Body part 8: Confidence = 0.07821206748485565, Point = (23, 33)
# Body part 9: Confidence = 0.018799202516674995, Point = (23, 38)
# Body part 10: Confidence = 0.008355891332030296, Point = (43, 2)
# Body part 11: Confidence = 0.08197858929634094, Point = (25, 37)
# Body part 12: Confidence = 0.010968903079628944, Point = (23, 37)
# Body part 13: Confidence = 0.00965905375778675, Point = (45, 1)
# Body part 14: Confidence = 0.701640248298645, Point = (23, 10)
# Body part 15: Confidence = 0.7987396121025085, Point = (25, 10)
# Body part 16: Confidence = 0.5268517732620239, Point = (22, 10)
# Body part 17: Confidence = 0.6628182530403137, Point = (26, 10)
# Body part 18: Confidence = 1.0033468008041382, Point = (44, 30)
# Body part 0: Confidence = 0.7126069068908691, Point = (24, 11)
# Body part 1: Confidence = 0.5681906938552856, Point = (26, 19)
# Body part 2: Confidence = 0.6355252861976624, Point = (22, 19)
# Body part 3: Confidence = 0.09549620747566223, Point = (22, 29)
# Body part 4: Confidence = 0.06696953624486923, Point = (24, 35)
# Body part 5: Confidence = 0.4749690890312195, Point = (29, 18)
# Body part 6: Confidence = 0.2736193537712097, Point = (30, 29)
# Body part 7: Confidence = 0.24724535644054413, Point = (25, 35)
# Body part 8: Confidence = 0.08290703594684601, Point = (23, 33)
# Body part 9: Confidence = 0.018122266978025436, Point = (24, 9)
# Body part 10: Confidence = 0.008355570957064629, Point = (43, 2)
# Body part 11: Confidence = 0.09916789829730988, Point = (25, 37)
# Body part 12: Confidence = 0.010221571661531925, Point = (23, 37)
# Body part 13: Confidence = 0.009658681228756905, Point = (45, 1)
# Body part 14: Confidence = 0.6923860907554626, Point = (23, 10)
# Body part 15: Confidence = 0.7992421984672546, Point = (25, 10)
# Body part 16: Confidence = 0.5539246797561646, Point = (22, 10)
# Body part 17: Confidence = 0.6667441725730896, Point = (26, 10)
# Body part 18: Confidence = 1.0036084651947021, Point = (44, 30)
# Body part 0: Confidence = 0.7519827485084534, Point = (24, 11)
# Body part 1: Confidence = 0.5818844437599182, Point = (25, 18)
# Body part 2: Confidence = 0.6483410596847534, Point = (22, 19)
# Body part 3: Confidence = 0.0992668867111206, Point = (22, 29)
# Body part 4: Confidence = 0.06607478111982346, Point = (24, 35)
# Body part 5: Confidence = 0.4957469701766968, Point = (29, 18)
# Body part 6: Confidence = 0.2972501516342163, Point = (30, 29)
# Body part 7: Confidence = 0.2327413260936737, Point = (25, 35)
# Body part 8: Confidence = 0.08793190121650696, Point = (23, 34)
# Body part 9: Confidence = 0.020262248814105988, Point = (23, 38)
# Body part 10: Confidence = 0.008313855156302452, Point = (43, 2)
# Body part 11: Confidence = 0.11178634315729141, Point = (25, 37)
# Body part 12: Confidence = 0.011612996459007263, Point = (23, 37)
# Body part 13: Confidence = 0.009656233713030815, Point = (45, 1)
# Body part 14: Confidence = 0.7425391674041748, Point = (23, 10)
# Body part 15: Confidence = 0.8125008344650269, Point = (25, 10)
# Body part 16: Confidence = 0.5276324152946472, Point = (22, 10)
# Body part 17: Confidence = 0.670248806476593, Point = (26, 10)
# Body part 18: Confidence = 1.0033104419708252, Point = (44, 30)
# Body part 0: Confidence = 0.7450358271598816, Point = (24, 11)
# Body part 1: Confidence = 0.5874123573303223, Point = (25, 18)
# Body part 2: Confidence = 0.6515986919403076, Point = (22, 19)
# Body part 3: Confidence = 0.09513995051383972, Point = (22, 29)
# Body part 4: Confidence = 0.062139302492141724, Point = (24, 35)
# Body part 5: Confidence = 0.5209652185440063, Point = (29, 18)
# Body part 6: Confidence = 0.36678996682167053, Point = (30, 29)
# Body part 7: Confidence = 0.20226342976093292, Point = (25, 35)
# Body part 8: Confidence = 0.09692561626434326, Point = (23, 34)
# Body part 9: Confidence = 0.02522016316652298, Point = (23, 38)
# Body part 10: Confidence = 0.008461665362119675, Point = (43, 2)
# Body part 11: Confidence = 0.11834990233182907, Point = (25, 37)
# Body part 12: Confidence = 0.0121763339266181, Point = (23, 37)
# Body part 13: Confidence = 0.009659498929977417, Point = (45, 1)
# Body part 14: Confidence = 0.7447471022605896, Point = (23, 10)
# Body part 15: Confidence = 0.8157078623771667, Point = (25, 10)
# Body part 16: Confidence = 0.5373468399047852, Point = (22, 10)
# Body part 17: Confidence = 0.6670981049537659, Point = (26, 10)
# Body part 18: Confidence = 1.0035966634750366, Point = (44, 30)
# Body part 0: Confidence = 0.750114917755127, Point = (24, 11)
# Body part 1: Confidence = 0.6013171076774597, Point = (25, 18)
# Body part 2: Confidence = 0.6453890204429626, Point = (22, 19)
# Body part 3: Confidence = 0.0823032408952713, Point = (22, 29)
# Body part 4: Confidence = 0.05933140963315964, Point = (24, 35)
# Body part 5: Confidence = 0.5292497277259827, Point = (29, 18)
# Body part 6: Confidence = 0.3824332654476166, Point = (30, 29)
# Body part 7: Confidence = 0.1746751219034195, Point = (26, 35)
# Body part 8: Confidence = 0.09574006497859955, Point = (23, 34)
# Body part 9: Confidence = 0.0362350158393383, Point = (23, 38)
# Body part 10: Confidence = 0.007622493430972099, Point = (24, 10)
# Body part 11: Confidence = 0.12627483904361725, Point = (26, 37)
# Body part 12: Confidence = 0.013360114768147469, Point = (28, 39)
# Body part 13: Confidence = 0.010241827927529812, Point = (45, 1)
# Body part 14: Confidence = 0.748038113117218, Point = (23, 10)
# Body part 15: Confidence = 0.8216841816902161, Point = (25, 10)
# Body part 16: Confidence = 0.5318275690078735, Point = (22, 11)
# Body part 17: Confidence = 0.6662299036979675, Point = (26, 10)
# Body part 18: Confidence = 1.0037611722946167, Point = (44, 30)
# Body part 0: Confidence = 0.7585065364837646, Point = (24, 11)
# Body part 1: Confidence = 0.6100698113441467, Point = (25, 18)
# Body part 2: Confidence = 0.6423280239105225, Point = (22, 19)
# Body part 3: Confidence = 0.08080658316612244, Point = (22, 29)
# Body part 4: Confidence = 0.0632425993680954, Point = (24, 35)
# Body part 5: Confidence = 0.544116199016571, Point = (29, 18)
# Body part 6: Confidence = 0.4661737382411957, Point = (30, 29)
# Body part 7: Confidence = 0.2654406428337097, Point = (26, 35)
# Body part 8: Confidence = 0.11726349592208862, Point = (23, 34)
# Body part 9: Confidence = 0.058672912418842316, Point = (23, 38)
# Body part 10: Confidence = 0.014114243909716606, Point = (25, 45)
# Body part 11: Confidence = 0.17127522826194763, Point = (26, 36)
# Body part 12: Confidence = 0.02432510256767273, Point = (23, 38)
# Body part 13: Confidence = 0.010074028745293617, Point = (45, 1)
# Body part 14: Confidence = 0.7620624303817749, Point = (23, 10)
# Body part 15: Confidence = 0.82244873046875, Point = (25, 10)
# Body part 16: Confidence = 0.5357004404067993, Point = (22, 11)
# Body part 17: Confidence = 0.6677955985069275, Point = (26, 10)
# Body part 18: Confidence = 1.0025743246078491, Point = (44, 30)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 21
#      19 frameHeight = frame.shape[0]
#      20 net.setInput(cv.dnn.blobFromImage(frame, 1.0, (inWidth, inHeight), (127.5, 127.5, 127.5), swapRB=True, crop=False))
# ---> 21 out = net.forward()
#      22 out = out[:, :19, :, :]
#      24 assert(len(BODY_PARTS) == out.shape[1])
#
# KeyboardInterrupt:

# %%
#camera
#perform this demo on video
#from google.colab.patches import cv2_imshow
cap = cv.VideoCapture(1)
cap.set(3,800) #height
cap.set(4,800) #width

if not cap.isOpened():
    cap = cv.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")

while cv.waitKey(1) < 0:
    hasFrame,frame = cap.read()
    if not hasFrame:
        cv.waitKey()
        break
        
    frameWidth = frame.shape[1]
    frameHeight = frame.shape[0]
    net.setInput(cv.dnn.blobFromImage(frame, 1.0, (inWidth, inHeight), (127.5, 127.5, 127.5), swapRB=True, crop=False))
    out = net.forward()
    out = out[:, :19, :, :]

    assert(len(BODY_PARTS) == out.shape[1])

    points = []

    for i in range(len(BODY_PARTS)):
        heatMap = out[0, i, :, :]
        _, conf, _, point = cv.minMaxLoc(heatMap)
        print(f"Body part {i}: Confidence = {conf}, Point = {point}")
        x = (frameWidth * point[0]) / out.shape[3]
        y = (frameHeight * point[1]) / out.shape[2]

        # Add a point if it's confidence is higher than threshold.
        points.append((int(x), int(y)) if conf > thr else None)

    for pair in POSE_PAIRS:
        partFrom = pair[0]
        partTo = pair[1]
        assert(partFrom in BODY_PARTS)
        assert(partTo in BODY_PARTS)

        idFrom = BODY_PARTS[partFrom]
        idTo = BODY_PARTS[partTo]

        if points[idFrom] and points[idTo]:
            cv.line(frame, points[idFrom], points[idTo], (0, 255, 0), 3)
            cv.ellipse(frame, points[idFrom], (3, 3), 0, 0, 360, (0, 0, 255), cv.FILLED)
            cv.ellipse(frame, points[idTo], (3, 3), 0, 0, 360, (0, 0, 255), cv.FILLED)

    t, _ = net.getPerfProfile()
    freq = cv.getTickFrequency() / 1000
    cv.putText(frame, '%.2fms' % (t / freq), (10, 20), cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0))

    cv.imshow('Pose Estimation Tutorial', frame)

# %%
import cv2 as cv
import numpy as np

# Load the pre-trained neural network model
net = cv.dnn.readNetFromTensorflow("graph_opt.pb") 

# Set the input size for the network
inWidth = 368
inHeight = 368
thr = 0.2  

# Define the BODY_PARTS and POSE_PAIRS
BODY_PARTS = {0: "Nose", 1: "Neck", 2: "RShoulder", 3: "RElbow", 4: "RWrist",
              5: "LShoulder", 6: "LElbow", 7: "LWrist", 8: "RHip", 9: "RKnee",
              10: "RAnkle", 11: "LHip", 12: "LKnee", 13: "LAnkle", 14: "REye",
              15: "LEye", 16: "REar", 17: "LEar", 18: "Background"}

POSE_PAIRS = [["Neck", "RShoulder"], ["Neck", "LShoulder"], ["RShoulder", "RElbow"],
              ["RElbow", "RWrist"], ["LShoulder", "LElbow"], ["LElbow", "LWrist"],
              ["Neck", "RHip"], ["RHip", "RKnee"], ["RKnee", "RAnkle"],
              ["Neck", "LHip"], ["LHip", "LKnee"], ["LKnee", "LAnkle"],
              ["Neck", "Nose"], ["Nose", "REye"], ["REye", "REar"],
              ["Nose", "LEye"], ["LEye", "LEar"]]

# Define the pose_estimation function
def pose_estimation(frame):
    frameWidth = frame.shape[1]
    frameHeight = frame.shape[0]
    net.setInput(cv.dnn.blobFromImage(frame, 1.0, (inWidth, inHeight), (127.5, 127.5, 127.5), swapRB=True, crop=False))
    out = net.forward()
    out = out[:, :19, :, :]

    assert(len(BODY_PARTS) == out.shape[1])

    points = []

    for i in range(len(BODY_PARTS)):
        heatMap = out[0, i, :, :]
        _, conf, _, point = cv.minMaxLoc(heatMap)
        x = (frameWidth * point[0]) / out.shape[3]
        y = (frameHeight * point[1]) / out.shape[2]

        points.append((int(x), int(y)) if conf > thr else None)

    return points

# Function to calculate the Euclidean distance between two points
def euclidean_distance(point1, point2):
    return np.linalg.norm(np.array(point1) - np.array(point2))

# Function to calculate the similarity percentage between two sets of keypoints
def calculate_similarity_percentage(keypoints1, keypoints2, max_distance=200):
    if len(keypoints1) != len(keypoints2):
        raise ValueError("Keypoints from both images must have the same length.")
    
    total_distance = 0
    valid_points = 0

    for kp1, kp2 in zip(keypoints1, keypoints2):
        if kp1 is not None and kp2 is not None:
            total_distance += euclidean_distance(kp1, kp2)
            valid_points += 1

    if valid_points == 0:
        return 0  # No valid points to compare

    average_distance = total_distance / valid_points
    similarity_percentage = max(0, 100 * (1 - average_distance / max_distance))
    
    return similarity_percentage

# Load the first image and extract keypoints
img = cv.imread("pose1.jpg")
keypoints_img1 = pose_estimation(img)

# Load the second image and extract keypoints
img2 = cv.imread("pose1.jpg")
keypoints_img2 = pose_estimation(img2)

# Calculate the similarity percentage between the two sets of keypoints
similarity_percentage = calculate_similarity_percentage(keypoints_img1, keypoints_img2)

print(f"The similarity between the two poses is {similarity_percentage:.2f}%")
# Out:
# The similarity between the two poses is 100.00%

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# Load the pre-trained neural network model
net = cv.dnn.readNetFromTensorflow("graph_opt.pb")

# Set the input size for the network
inWidth = 368
inHeight = 368
thr = 0.2

# Define the BODY_PARTS with names as keys
BODY_PARTS = {"Nose": 0, "Neck": 1, "RShoulder": 2, "RElbow": 3, "RWrist": 4,
              "LShoulder": 5, "LElbow": 6, "LWrist": 7, "RHip": 8, "RKnee": 9,
              "RAnkle": 10, "LHip": 11, "LKnee": 12, "LAnkle": 13, "REye": 14,
              "LEye": 15, "REar": 16, "LEar": 17, "Background": 18}

POSE_PAIRS = [["Neck", "RShoulder"], ["Neck", "LShoulder"], ["RShoulder", "RElbow"],
              ["RElbow", "RWrist"], ["LShoulder", "LElbow"], ["LElbow", "LWrist"],
              ["Neck", "RHip"], ["RHip", "RKnee"], ["RKnee", "RAnkle"],
              ["Neck", "LHip"], ["LHip", "LKnee"], ["LKnee", "LAnkle"],
              ["Neck", "Nose"], ["Nose", "REye"], ["REye", "REar"],
              ["Nose", "LEye"], ["LEye", "LEar"]]

# Pose estimation function with skeleton drawing
def pose_estimation(frame):
    if frame is None:
        raise ValueError("The image could not be loaded. Please check the file path.")
    
    frameWidth = frame.shape[1]
    frameHeight = frame.shape[0]
    net.setInput(cv.dnn.blobFromImage(frame, 1.0, (inWidth, inHeight), (127.5, 127.5, 127.5), swapRB=True, crop=False))
    out = net.forward()
    out = out[:, :19, :, :]

    assert(len(BODY_PARTS) == out.shape[1])

    points = []

    for i in range(len(BODY_PARTS)):
        heatMap = out[0, i, :, :]
        _, conf, _, point = cv.minMaxLoc(heatMap)
        x = (frameWidth * point[0]) / out.shape[3]
        y = (frameHeight * point[1]) / out.shape[2]
        
        # Only consider points with confidence above threshold
        points.append((int(x), int(y)) if conf > thr else None)

    # Draw skeleton
    for pair in POSE_PAIRS:
        partFrom = pair[0]
        partTo = pair[1]

        idFrom = BODY_PARTS[partFrom]
        idTo = BODY_PARTS[partTo]

        if points[idFrom] and points[idTo]:
            cv.line(frame, points[idFrom], points[idTo], (0, 255, 0), 3)
            cv.ellipse(frame, points[idFrom], (3, 3), 0, 0, 360, (0, 0, 255), cv.FILLED)
            cv.ellipse(frame, points[idTo], (3, 3), 0, 0, 360, (0, 0, 255), cv.FILLED)

    return points, frame

# Function to resize images to the same height
def resize_to_same_height(img1, img2):
    height1 = img1.shape[0]
    height2 = img2.shape[0]

    if height1 != height2:
        # Resize the second image to match the first image's height
        img2 = cv.resize(img2, (int(img2.shape[1] * (height1 / height2)), height1))

    return img1, img2

# Load and process the first image
img1 = cv.imread("pose1.jpg")
if img1 is None:
    print("Error loading pose1.jpg")

keypoints_img1, img1_with_pose = pose_estimation(img1)

# Load and process the second image
img2 = cv.imread("pose1.jpg")
if img2 is None:
    print("Error loading pose2.jpg")

keypoints_img2, img2_with_pose = pose_estimation(img2)

# Resize images to have the same height
img1_with_pose, img2_with_pose = resize_to_same_height(img1_with_pose, img2_with_pose)

# Combine both images side by side
combined_image = np.hstack((img1_with_pose, img2_with_pose))

# Convert BGR to RGB for matplotlib
combined_image_rgb = cv.cvtColor(combined_image, cv.COLOR_BGR2RGB)

# Display the combined image using matplotlib
plt.figure(figsize=(10, 6))
plt.imshow(combined_image_rgb)
plt.title("Pose Estimation and Matching")
plt.axis("off")  # Hide the axis
plt.show()
