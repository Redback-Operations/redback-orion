# %% [markdown]
# ## Pixel Per Second Feature
# Status: ***Completed***
#
# ### Purpose
# We wish to develop a feature to detect the speed of a dog. Ideally we wish to develop a feature that will give us km/h, but an initial we will develop a pixel per second feature. A speed feature will give us the ability to eventually:
# - Track average speed of a good
# - Track acceleration, particularly at the start of the race and final straight
# - Ability to notice checks easier (dogs slow down when they are checked
#
# ### How?
# We will use euclidean distance multiplied by frames per second
#
# ### Limitation
# The goodness of our pixel per second reading depend entirely on our ability to track the dogs. If a dog gets lost for a few moments (flickering of the box), then we lose the dogs speed. This has knock on effect to the rest of our features.

# %% [markdown]
# #### Installs for Collab

# %%
# !pip install opencv-python
# !pip install ultralytics
# !pip install numpy
# !pip install deep_sort_realtime
# !pip install supervision
# !pip install scipy
# !pip install requests

# %% [markdown]
# #### Imports

# %%
import cv2
import os
import requests
import numpy as np
from ultralytics import YOLO
import supervision as sv
from scipy.spatial.distance import euclidean
from deep_sort_realtime.deepsort_tracker import DeepSort

# %% [markdown]
# #### Downloading Inputs
# We are grabbing a video from our public bucket. Possible values:
# - 20240720WENG09_V.mp4
# - 20240720WENG04_V.mp4
# - 20240722NOTG06_V.mp4
# - 20240722NOTG08_V.mp4
# - 20240722SANG03_V.mp4
# - 20240724THMG05_V.mp4
# - 20240724THMG08_V.mp4
# - 20240724THMG10_V.mp4

# %%
video_url = "https://storage.googleapis.com/greyhound-vision-data/raw_videos/20240720WENG04_V.mp4"
local_path = os.path.join(os.getcwd(), "20240720WENG04_V.mp4")

response = requests.get(video_url)

if response.status_code == 200:
    with open(local_path, 'wb') as file:
        file.write(response.content)

# %% [markdown]
# #### Initialising Model & Set up
# The default value in the model is yolov8. This can easily be switched out to use the model produced by training notebook. Replace the content of the initiliser with the path of saved model.

# %%
model = YOLO("yolov8n.pt")

# Initialize the DeepSort tracker
tracker = DeepSort(max_age=30)

# Open the video file
cap = cv2.VideoCapture(local_path)

# Verify the output directory and permissions
output_dir = "./output"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

if not os.access(output_dir, os.W_OK):
    raise PermissionError(f"Write permission denied for the directory {output_dir}")

# Define the output video path
output_path = os.path.join(output_dir, "pixel_per_second.mp4")

assert cap.isOpened(), "Error reading video file"

# Get video properties
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Initialize VideoWriter with a successful FourCC code
fourcc_code = cv2.VideoWriter_fourcc(*"mp4v")
video_writer = cv2.VideoWriter(output_path, fourcc_code, fps, (w, h))

if not video_writer.isOpened():
    raise IOError(f"Error initializing video writer with path {output_path}")

# %% [markdown]
# #### Creation of calculate speed function

# %%
# Track previous positions of dogs to calculate speed
previous_positions = {}
box_annotator = sv.BoxAnnotator(thickness=4)

def calculate_speed(previous_position, current_position, fps):
    distance = euclidean(previous_position, current_position)
    speed = distance * fps  # Speed in pixels per second
    return speed

# %% [markdown]
# #### Main processing loop

# %%
# Process video frames
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    # Perform object detection
    results = model(frame, imgsz=1280)

    # Extract bounding boxes, confidences, and class IDs
    boxes = results[0].boxes.xyxy.cpu().numpy()
    confidences = results[0].boxes.conf.cpu().numpy()
    class_ids = results[0].boxes.cls.cpu().numpy().astype(int)

    # Prepare detections for tracking
    detections = []
    for i in range(len(boxes)):
        x1, y1, x2, y2 = boxes[i]
        bbox = [x1, y1, x2 - x1, y2 - y1]  # Convert to [x, y, w, h]
        detection = (bbox, confidences[i], class_ids[i])
        detections.append(detection)

    # Update the tracker with detections
    tracked_objects = tracker.update_tracks(detections, frame=frame)

    # Annotate the frame with boxes and labels
    for obj in tracked_objects:
        if not obj.is_confirmed():
            continue

        box = obj.to_ltwh()  # Get the bounding box as [left, top, width, height]
        obj_id = obj.track_id
        class_id = obj.det_class

        if class_id == 16:  # Assuming '16' is the class ID for dogs
            center = (int(box[0] + box[2] / 2), int(box[1] + box[3] / 2))

            if obj_id in previous_positions:
                speed = calculate_speed(previous_positions[obj_id], center, fps)
                label = f"ID {obj_id} | Speed: {speed:.2f} px/s"
            else:
                label = f"ID {obj_id} | Speed: Calculating..."

            previous_positions[obj_id] = center

            # Draw the bounding box
            cv2.rectangle(frame, (int(box[0]), int(box[1])), (int(box[0] + box[2]), int(box[1] + box[3])), (0, 255, 0), 2)
            # Put the label on top of the bounding box
            cv2.putText(frame, label, (int(box[0]), int(box[1]) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)

    # Write the processed frame to the output video
    video_writer.write(frame)
# Out:
# 0: 736x1280 1 person, 28.8ms
# Speed: 4.6ms preprocess, 28.8ms inference, 76.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3.0ms
# Speed: 4.7ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3.0ms
# Speed: 3.7ms preprocess, 3.0ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3.1ms
# Speed: 3.9ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3.1ms
# Speed: 3.7ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3.0ms
# Speed: 3.6ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3.0ms
# Speed: 3.6ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3.4ms
# Speed: 4.7ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 dog, 3.4ms
# Speed: 4.7ms preprocess, 3.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 dog, 3.1ms
# Speed: 7.5ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 dog, 3.0ms
# Speed: 3.5ms preprocess, 3.0ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 train, 3.1ms
# Speed: 3.7ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 dog, 3.0ms
# Speed: 3.5ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3.0ms
# Speed: 3.8ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3.1ms
# Speed: 3.6ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3.1ms
# Speed: 3.7ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3.1ms
# Speed: 3.9ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 3.0ms
# Speed: 3.5ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3.0ms
# Speed: 3.5ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 train, 1 dog, 3.0ms
# Speed: 3.5ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 train, 3.1ms
# Speed: 3.2ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 train, 3.0ms
# Speed: 3.3ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 train, 3.0ms
# Speed: 3.3ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 dog, 3.1ms
# Speed: 3.5ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 dog, 3.1ms
# Speed: 3.7ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 train, 3.1ms
# Speed: 3.8ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3.0ms
# Speed: 3.4ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 1 traffic light, 1 chair, 3.0ms
# Speed: 3.5ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.0ms
# Speed: 4.3ms preprocess, 3.0ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.0ms
# Speed: 4.1ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 6.8ms
# Speed: 5.3ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 3.0ms
# Speed: 4.2ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3.0ms
# Speed: 3.6ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3.0ms
# Speed: 4.1ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 train, 3.0ms
# Speed: 4.2ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3.1ms
# Speed: 3.5ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3.0ms
# Speed: 4.3ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 3.0ms
# Speed: 4.1ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.0ms
# Speed: 3.7ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 7.1ms
# Speed: 5.0ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 7.2ms
# Speed: 5.8ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 1 dog, 3.5ms
# Speed: 5.0ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 3.5ms
# Speed: 5.0ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 3.5ms
# Speed: 4.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 3.4ms
# Speed: 5.1ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 1 train, 3.5ms
# Speed: 7.0ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 train, 1 tie, 4.1ms
# Speed: 6.3ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 1 train, 3.5ms
# Speed: 5.6ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 1 train, 3.5ms
# Speed: 4.4ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 1 train, 3.4ms
# Speed: 4.6ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.4ms
# Speed: 4.6ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 3.4ms
# Speed: 4.8ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 3.4ms
# Speed: 4.4ms preprocess, 3.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 1 train, 3.4ms
# Speed: 5.6ms preprocess, 3.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 1 train, 3.5ms
# Speed: 4.9ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 train, 3.5ms
# Speed: 4.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 train, 3.4ms
# Speed: 5.0ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3.5ms
# Speed: 4.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 1 train, 3.4ms
# Speed: 5.6ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 train, 3.5ms
# Speed: 5.6ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 train, 3.6ms
# Speed: 5.5ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 train, 3.6ms
# Speed: 5.4ms preprocess, 3.6ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 train, 3.5ms
# Speed: 5.0ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 train, 3.5ms
# Speed: 5.6ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 train, 3.5ms
# Speed: 4.7ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 train, 3.5ms
# Speed: 4.9ms preprocess, 3.5ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 1 train, 3.5ms
# Speed: 4.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 train, 3.4ms
# Speed: 5.0ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 3.5ms
# Speed: 5.1ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 1 traffic light, 3.6ms
# Speed: 6.5ms preprocess, 3.6ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 1 train, 3.4ms
# Speed: 5.7ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.4ms
# Speed: 4.6ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 3.5ms
# Speed: 4.4ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 3.4ms
# Speed: 4.7ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 3.4ms
# Speed: 4.5ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 3.6ms
# Speed: 4.8ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 3.4ms
# Speed: 4.8ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 3.5ms
# Speed: 4.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 3.7ms
# Speed: 5.1ms preprocess, 3.7ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 3.4ms
# Speed: 3.9ms preprocess, 3.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 3.4ms
# Speed: 5.5ms preprocess, 3.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 3.5ms
# Speed: 4.6ms preprocess, 3.5ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.4ms
# Speed: 4.7ms preprocess, 3.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.5ms
# Speed: 5.1ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.5ms
# Speed: 4.0ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 3.5ms
# Speed: 4.0ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 3.5ms
# Speed: 4.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 3.4ms
# Speed: 4.7ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.5ms
# Speed: 4.2ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.4ms
# Speed: 4.6ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.4ms
# Speed: 3.7ms preprocess, 3.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 chair, 3.4ms
# Speed: 5.7ms preprocess, 3.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 3.6ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 chair, 3.4ms
# Speed: 4.6ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.5ms
# Speed: 5.4ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 8 persons, 3.5ms
# Speed: 4.0ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.6ms
# Speed: 5.8ms preprocess, 3.6ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 3.2ms preprocess, 3.5ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 4.3ms
# Speed: 3.0ms preprocess, 4.3ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.4ms
# Speed: 3.0ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 6.3ms
# Speed: 3.3ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 5.2ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.6ms
# Speed: 3.0ms preprocess, 3.6ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.4ms
# Speed: 4.1ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.7ms
# Speed: 3.1ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.6ms
# Speed: 3.0ms preprocess, 3.6ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.8ms
# Speed: 4.1ms preprocess, 3.8ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.4ms
# Speed: 4.5ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.7ms
# Speed: 2.9ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 1 chair, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 3.7ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.4ms
# Speed: 3.0ms preprocess, 3.4ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.7ms
# Speed: 2.9ms preprocess, 3.7ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.8ms
# Speed: 2.9ms preprocess, 3.8ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 train, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 1 train, 3.5ms
# Speed: 4.3ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 5.5ms
# Speed: 2.9ms preprocess, 5.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 1 dog, 3.4ms
# Speed: 3.0ms preprocess, 3.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.6ms
# Speed: 2.9ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.6ms
# Speed: 3.9ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 3.8ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 5.8ms
# Speed: 2.8ms preprocess, 5.8ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 3.4ms
# Speed: 3.0ms preprocess, 3.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 4.4ms
# Speed: 2.8ms preprocess, 4.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 3.4ms
# Speed: 3.6ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 4.6ms
# Speed: 2.8ms preprocess, 4.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 5.1ms
# Speed: 2.9ms preprocess, 5.1ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 4.7ms
# Speed: 2.9ms preprocess, 4.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.6ms
# Speed: 2.9ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.6ms
# Speed: 2.8ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.6ms
# Speed: 2.8ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 8.7ms
# Speed: 2.9ms preprocess, 8.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 4.3ms
# Speed: 2.9ms preprocess, 4.3ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.4ms
# Speed: 2.9ms preprocess, 3.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.4ms
# Speed: 2.9ms preprocess, 3.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 4.7ms
# Speed: 2.9ms preprocess, 4.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.4ms
# Speed: 2.9ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 4.0ms
# Speed: 2.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.6ms
# Speed: 4.3ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.4ms
# Speed: 3.8ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 4.5ms
# Speed: 2.8ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 5.0ms
# Speed: 2.8ms preprocess, 5.0ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 5.2ms
# Speed: 2.8ms preprocess, 5.2ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.4ms
# Speed: 3.2ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.6ms
# Speed: 6.0ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.7ms
# Speed: 2.8ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.4ms
# Speed: 4.2ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 8 persons, 3.5ms
# Speed: 3.6ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 9 persons, 3.5ms
# Speed: 4.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 8 persons, 3.8ms
# Speed: 2.8ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 9 persons, 3.4ms
# Speed: 3.3ms preprocess, 3.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.6ms
# Speed: 3.9ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.4ms
# Speed: 2.8ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.4ms
# Speed: 2.8ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.6ms
# Speed: 4.2ms preprocess, 3.6ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 3.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.8ms
# Speed: 2.9ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.8ms
# Speed: 2.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.4ms
# Speed: 2.9ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.4ms
# Speed: 3.2ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.4ms
# Speed: 3.3ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 4.9ms
# Speed: 2.6ms preprocess, 4.9ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.6ms
# Speed: 2.6ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.0ms
# Speed: 2.3ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.0ms
# Speed: 2.3ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.4ms
# Speed: 2.7ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 15.4ms
# Speed: 17.7ms preprocess, 15.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 5.2ms
# Speed: 2.8ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.4ms
# Speed: 2.7ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 5.3ms
# Speed: 2.6ms preprocess, 5.3ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.4ms
# Speed: 2.7ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.4ms
# Speed: 3.3ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 4.4ms
# Speed: 2.6ms preprocess, 4.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 4.7ms
# Speed: 2.6ms preprocess, 4.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.8ms
# Speed: 2.9ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.6ms
# Speed: 2.7ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.4ms
# Speed: 2.6ms preprocess, 3.4ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.7ms
# Speed: 2.8ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.7ms
# Speed: 3.4ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.8ms
# Speed: 2.8ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 3.9ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 4.6ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 5.3ms
# Speed: 3.9ms preprocess, 5.3ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.6ms
# Speed: 3.2ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.6ms
# Speed: 3.0ms preprocess, 3.6ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.5ms
# Speed: 3.5ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 1 tv, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 1 tv, 3.6ms
# Speed: 2.8ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 1 train, 1 tv, 3.5ms
# Speed: 2.6ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 1 train, 3.6ms
# Speed: 2.9ms preprocess, 3.6ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 1 train, 3.9ms
# Speed: 2.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 8 persons, 1 train, 3.6ms
# Speed: 2.7ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 1 train, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 8 persons, 1 train, 3.9ms
# Speed: 2.8ms preprocess, 3.9ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 1 train, 3.6ms
# Speed: 3.5ms preprocess, 3.6ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.4ms
# Speed: 3.1ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.7ms
# Speed: 3.7ms preprocess, 3.7ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.6ms
# Speed: 2.9ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.4ms
# Speed: 2.9ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 1 tv, 3.5ms
# Speed: 3.5ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.4ms
# Speed: 2.8ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.4ms
# Speed: 2.8ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.9ms
# Speed: 2.8ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 5.3ms
# Speed: 2.7ms preprocess, 5.3ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.4ms
# Speed: 2.8ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.6ms
# Speed: 3.4ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 1 train, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 4.4ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.6ms
# Speed: 3.1ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.6ms
# Speed: 6.6ms preprocess, 3.6ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.9ms
# Speed: 2.7ms preprocess, 3.9ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.5ms
# Speed: 3.1ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 3.6ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.9ms
# Speed: 2.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.9ms
# Speed: 2.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 1 train, 3.6ms
# Speed: 2.8ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.5ms
# Speed: 5.3ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 1 train, 5.0ms
# Speed: 2.7ms preprocess, 5.0ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 1 train, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 4.3ms preprocess, 3.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 3.4ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 5.0ms
# Speed: 3.1ms preprocess, 5.0ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.9ms
# Speed: 2.8ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 4.4ms
# Speed: 2.7ms preprocess, 4.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.6ms
# Speed: 3.0ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 3.3ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.4ms
# Speed: 3.4ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 4.4ms
# Speed: 3.3ms preprocess, 4.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.8ms
# Speed: 3.4ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.6ms
# Speed: 2.7ms preprocess, 3.6ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.8ms
# Speed: 2.8ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.5ms
# Speed: 3.4ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.7ms
# Speed: 2.8ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.4ms
# Speed: 2.8ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.4ms
# Speed: 2.8ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.5ms
# Speed: 3.3ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 8 persons, 3.5ms
# Speed: 4.4ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 8 persons, 3.8ms
# Speed: 2.8ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 8 persons, 3.9ms
# Speed: 4.4ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 4.5ms
# Speed: 2.9ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.5ms
# Speed: 4.1ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.6ms
# Speed: 3.4ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.5ms
# Speed: 3.4ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 4.9ms
# Speed: 2.6ms preprocess, 4.9ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.5ms
# Speed: 3.4ms preprocess, 3.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 4.2ms
# Speed: 2.7ms preprocess, 4.2ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.1ms
# Speed: 4.6ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 5.4ms
# Speed: 3.1ms preprocess, 5.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 5.1ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 3.7ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 3.7ms preprocess, 3.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.4ms
# Speed: 2.8ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 3.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 3.4ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.5ms
# Speed: 3.3ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.6ms
# Speed: 4.3ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 3.4ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.8ms
# Speed: 2.9ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 4.4ms
# Speed: 2.9ms preprocess, 4.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 3.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.7ms
# Speed: 2.9ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.6ms
# Speed: 3.5ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.7ms
# Speed: 2.8ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.1ms
# Speed: 2.7ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 3.1ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 4.4ms preprocess, 3.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.6ms
# Speed: 2.8ms preprocess, 3.6ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.7ms
# Speed: 2.8ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.9ms
# Speed: 2.9ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.6ms
# Speed: 2.8ms preprocess, 3.6ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 handbag, 3.6ms
# Speed: 3.4ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.7ms
# Speed: 2.9ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 4.7ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.4ms
# Speed: 2.8ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.5ms
# Speed: 2.5ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.7ms
# Speed: 2.8ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 3.7ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.6ms
# Speed: 6.0ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 5.4ms
# Speed: 3.0ms preprocess, 5.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 3.6ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 4.6ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.4ms
# Speed: 2.9ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.6ms
# Speed: 3.1ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.4ms
# Speed: 2.8ms preprocess, 3.4ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.6ms
# Speed: 2.7ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 4.8ms
# Speed: 2.7ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.6ms
# Speed: 2.8ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 4.2ms
# Speed: 2.7ms preprocess, 4.2ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.4ms
# Speed: 2.8ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 4.7ms
# Speed: 2.8ms preprocess, 4.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.4ms
# Speed: 3.0ms preprocess, 3.4ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 29.0ms
# Speed: 4.6ms preprocess, 29.0ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 5.6ms
# Speed: 2.8ms preprocess, 5.6ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 4.4ms
# Speed: 2.8ms preprocess, 4.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.6ms
# Speed: 2.9ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 8 persons, 5.0ms
# Speed: 2.8ms preprocess, 5.0ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 4.4ms
# Speed: 3.8ms preprocess, 4.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 7 persons, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 8 persons, 1 train, 3.5ms
# Speed: 3.5ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.5ms
# Speed: 4.6ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 3.4ms
# Speed: 2.8ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 9 persons, 4.8ms
# Speed: 2.7ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 8 persons, 3.5ms
# Speed: 5.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 8 persons, 3.5ms
# Speed: 3.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 14 persons, 1 train, 3.6ms
# Speed: 3.8ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 10 persons, 4.9ms
# Speed: 3.0ms preprocess, 4.9ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 12 persons, 1 train, 1 dog, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 10 persons, 1 train, 1 dog, 6.2ms
# Speed: 2.7ms preprocess, 6.2ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 train, 5.7ms
# Speed: 2.7ms preprocess, 5.7ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 train, 1 dog, 1 tv, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 10 persons, 1 dog, 1 horse, 1 tv, 4.9ms
# Speed: 2.8ms preprocess, 4.9ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 3 dogs, 1 horse, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 10 persons, 1 horse, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 9 persons, 1 train, 1 dog, 1 tv, 3.5ms
# Speed: 3.4ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 6 persons, 1 bus, 1 train, 3 horses, 2 cows, 1 tv, 3.5ms
# ...
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 3.0ms
# Speed: 1.9ms preprocess, 3.0ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.2ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.1ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 3.2ms
# Speed: 1.9ms preprocess, 3.2ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 3.0ms
# Speed: 1.9ms preprocess, 3.0ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 3.1ms
# Speed: 2.0ms preprocess, 3.1ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 3.0ms
# Speed: 1.9ms preprocess, 3.0ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.1ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 3.0ms
# Speed: 1.9ms preprocess, 3.0ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.1ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 4.3ms
# Speed: 2.0ms preprocess, 4.3ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 3.0ms
# Speed: 2.7ms preprocess, 3.0ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 3.2ms
# Speed: 2.8ms preprocess, 3.2ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.2ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 3.0ms
# Speed: 2.4ms preprocess, 3.0ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 3.0ms
# Speed: 1.9ms preprocess, 3.0ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.3ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.2ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 3.0ms
# Speed: 2.2ms preprocess, 3.0ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 3.0ms
# Speed: 1.9ms preprocess, 3.0ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.0ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 1.9ms preprocess, 2.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 2.9ms
# Speed: 2.2ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 736, 1280)
# Video frame is empty or video processing has been successfully completed.

# %% [markdown]
# #### Clean up

# %%
cap.release()
video_writer.release()
cv2.destroyAllWindows()

print(f"Processed video saved to {output_path}")
# Out:
# Processed video saved to ./output/pixel_per_second.mp4
