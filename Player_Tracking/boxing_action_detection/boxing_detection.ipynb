# %%
# !pip install ultralytics==8.0.196
# !pip install opencv-python

# %%
import cv2
import os
from ultralytics import YOLO

# %%
model = YOLO('model/best.pt')

# %%
# Function to process each frame of the boxing match and detect actions
def process_frame_for_actions(frame, conf_threshold=0.7, iou_threshold=0.5):
    results = model.predict(frame, conf=conf_threshold, iou=iou_threshold)
    
    # Iterate through the results (detections) for this frame
    for result in results:
        detections = result.boxes  # Get the bounding boxes
        for i in range(detections.xyxy.shape[0]):
            # Extract bounding box coordinates
            x1, y1, x2, y2 = detections.xyxy[i][:4].int().tolist()
            
            # Extract confidence score and label ID
            confidence = detections.conf[i].item()
            label_id = detections.cls[i].int().item()
            
            # Get the label name using the label ID (standing, kicking, punching,)
            label = model.names[label_id]

            # Only process if confidence is above the threshold
            if confidence >= conf_threshold:
                border_color = (255, 0, 0)  # Set color for boxing actions bounding box
                border_thickness = 3  # Set border thickness

                # Draw the bounding box around the detected action
                cv2.rectangle(frame, (x1, y1), (x2, y2), border_color, border_thickness)

                # Label the bounding box with the action name and confidence score
                cv2.putText(frame, f'{label} {confidence:.2f}', 
                            (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, border_color, 2)

    return results, frame  # Return the detection results and the processed frame


input_video_path = 'data/test_data/mma_test.mp4'
output_video_path = 'data/output_data/mma_output.mp4'

cap = cv2.VideoCapture(input_video_path)

fps = int(cap.get(cv2.CAP_PROP_FPS))
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# Initialize counters
punch_count = 0
kick_count = 0
last_punch_frame = -10  # Initial large negative value to ensure first detection is counted
last_kick_frame = -10
frame_number = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Process each frame for boxing actions with specified conf and iou thresholds
    results, processed_frame = process_frame_for_actions(frame, conf_threshold=0.7, iou_threshold=0.5) 

    # Iterate through the detection results to count punches and kicks
    for result in results:
        detections = result.boxes.data
        for detection in detections:
            class_id = int(detection[5])
            label = result.names[class_id]

            # Check label and ensure a cooldown period has passed before counting again
            if label == 'punch' and frame_number > last_punch_frame + 15:  # Adjusted frame gap as necessary
                punch_count += 1
                last_punch_frame = frame_number
            elif label == 'kick' and frame_number > last_kick_frame + 15:  # Adjusted frame gap
                kick_count += 1
                last_kick_frame = frame_number

    # Add the punch and kick count to the frame
    cv2.putText(processed_frame, f'Punches: {punch_count}  Kicks: {kick_count}', 
                (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

    # Save the processed frame to the output video
    out.write(processed_frame)

    # Display the processed frame
    cv2.imshow('Boxing Action Detection', processed_frame)

    # Exit if 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    frame_number += 1

# Release video resources
cap.release()
out.release()
cv2.destroyAllWindows()

# Print the final punch and kick counts
print(f'Total Punches: {punch_count}')
print(f'Total Kicks: {kick_count}')
# Out:
# 0: 512x800 1 punch, 571.6ms
# Speed: 11.3ms preprocess, 571.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 411.4ms
# Speed: 0.0ms preprocess, 411.4ms inference, 8.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 466.4ms
# Speed: 7.6ms preprocess, 466.4ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 462.0ms
# Speed: 5.6ms preprocess, 462.0ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 412.2ms
# Speed: 8.5ms preprocess, 412.2ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 392.9ms
# Speed: 6.7ms preprocess, 392.9ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 419.6ms
# Speed: 5.5ms preprocess, 419.6ms inference, 8.3ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 392.5ms
# Speed: 8.6ms preprocess, 392.5ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 391.2ms
# Speed: 15.9ms preprocess, 391.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 411.5ms
# Speed: 5.1ms preprocess, 411.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 397.4ms
# Speed: 9.1ms preprocess, 397.4ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 380.2ms
# Speed: 6.5ms preprocess, 380.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 401.2ms
# Speed: 6.1ms preprocess, 401.2ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 386.5ms
# Speed: 5.5ms preprocess, 386.5ms inference, 2.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 402.9ms
# Speed: 7.9ms preprocess, 402.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 406.6ms
# Speed: 10.6ms preprocess, 406.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 398.8ms
# Speed: 5.9ms preprocess, 398.8ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 395.7ms
# Speed: 9.7ms preprocess, 395.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 393.8ms
# Speed: 8.9ms preprocess, 393.8ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 409.0ms
# Speed: 16.5ms preprocess, 409.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 395.9ms
# Speed: 4.1ms preprocess, 395.9ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 384.6ms
# Speed: 9.4ms preprocess, 384.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 398.3ms
# Speed: 8.8ms preprocess, 398.3ms inference, 3.3ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 413.4ms
# Speed: 6.8ms preprocess, 413.4ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 400.6ms
# Speed: 9.2ms preprocess, 400.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 400.5ms
# Speed: 14.8ms preprocess, 400.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 400.0ms
# Speed: 5.9ms preprocess, 400.0ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 391.0ms
# Speed: 6.8ms preprocess, 391.0ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 409.9ms
# Speed: 8.7ms preprocess, 409.9ms inference, 5.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 408.6ms
# Speed: 8.5ms preprocess, 408.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 388.4ms
# Speed: 9.5ms preprocess, 388.4ms inference, 3.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 402.7ms
# Speed: 8.0ms preprocess, 402.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 405.1ms
# Speed: 7.8ms preprocess, 405.1ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 396.6ms
# Speed: 8.7ms preprocess, 396.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 388.7ms
# Speed: 8.7ms preprocess, 388.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 387.5ms
# Speed: 9.7ms preprocess, 387.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 403.4ms
# Speed: 12.2ms preprocess, 403.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 384.9ms
# Speed: 9.1ms preprocess, 384.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 390.5ms
# Speed: 9.8ms preprocess, 390.5ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 400.5ms
# Speed: 9.0ms preprocess, 400.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 390.3ms
# Speed: 3.1ms preprocess, 390.3ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 403.9ms
# Speed: 6.2ms preprocess, 403.9ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 400.6ms
# Speed: 7.7ms preprocess, 400.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 399.4ms
# Speed: 7.1ms preprocess, 399.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 410.1ms
# Speed: 9.9ms preprocess, 410.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 399.1ms
# Speed: 12.1ms preprocess, 399.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 388.5ms
# Speed: 8.5ms preprocess, 388.5ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 374.9ms
# Speed: 8.3ms preprocess, 374.9ms inference, 5.3ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 400.0ms
# Speed: 9.7ms preprocess, 400.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 562.7ms
# Speed: 7.8ms preprocess, 562.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 383.0ms
# Speed: 8.2ms preprocess, 383.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 581.5ms
# Speed: 0.0ms preprocess, 581.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 458.0ms
# Speed: 8.6ms preprocess, 458.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 395.5ms
# Speed: 6.1ms preprocess, 395.5ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 410.2ms
# Speed: 8.1ms preprocess, 410.2ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 388.7ms
# Speed: 8.4ms preprocess, 388.7ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 399.4ms
# Speed: 5.6ms preprocess, 399.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 386.5ms
# Speed: 7.8ms preprocess, 386.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 397.8ms
# Speed: 8.2ms preprocess, 397.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 395.1ms
# Speed: 9.7ms preprocess, 395.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 385.6ms
# Speed: 7.3ms preprocess, 385.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 390.0ms
# Speed: 8.0ms preprocess, 390.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 405.5ms
# Speed: 9.4ms preprocess, 405.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 393.7ms
# Speed: 8.1ms preprocess, 393.7ms inference, 7.7ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 397.5ms
# Speed: 6.5ms preprocess, 397.5ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 410.5ms
# Speed: 7.5ms preprocess, 410.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 385.7ms
# Speed: 6.7ms preprocess, 385.7ms inference, 3.2ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 407.4ms
# Speed: 6.9ms preprocess, 407.4ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 395.5ms
# Speed: 8.5ms preprocess, 395.5ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 378.2ms
# Speed: 7.7ms preprocess, 378.2ms inference, 2.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 399.4ms
# Speed: 9.5ms preprocess, 399.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 398.7ms
# Speed: 7.1ms preprocess, 398.7ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 393.4ms
# Speed: 6.3ms preprocess, 393.4ms inference, 3.2ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 372.2ms
# Speed: 8.0ms preprocess, 372.2ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 406.2ms
# Speed: 6.7ms preprocess, 406.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 410.4ms
# Speed: 6.4ms preprocess, 410.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 402.2ms
# Speed: 9.6ms preprocess, 402.2ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 397.4ms
# Speed: 5.7ms preprocess, 397.4ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 388.4ms
# Speed: 10.8ms preprocess, 388.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 397.4ms
# Speed: 9.4ms preprocess, 397.4ms inference, 5.8ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 392.3ms
# Speed: 9.7ms preprocess, 392.3ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 398.3ms
# Speed: 10.1ms preprocess, 398.3ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 388.0ms
# Speed: 14.0ms preprocess, 388.0ms inference, 6.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 407.3ms
# Speed: 9.6ms preprocess, 407.3ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 388.7ms
# Speed: 8.9ms preprocess, 388.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 393.0ms
# Speed: 9.7ms preprocess, 393.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 391.0ms
# Speed: 8.2ms preprocess, 391.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 389.9ms
# Speed: 11.0ms preprocess, 389.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 399.3ms
# Speed: 6.5ms preprocess, 399.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 401.9ms
# Speed: 2.9ms preprocess, 401.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 559.3ms
# Speed: 7.6ms preprocess, 559.3ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 601.0ms
# Speed: 8.8ms preprocess, 601.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 795.3ms
# Speed: 15.8ms preprocess, 795.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 662.2ms
# Speed: 7.0ms preprocess, 662.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 487.2ms
# Speed: 2.3ms preprocess, 487.2ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 330.2ms
# Speed: 2.7ms preprocess, 330.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 362.0ms
# Speed: 6.5ms preprocess, 362.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 414.7ms
# Speed: 9.3ms preprocess, 414.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 467.1ms
# Speed: 9.8ms preprocess, 467.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 509.3ms
# Speed: 0.0ms preprocess, 509.3ms inference, 5.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 457.2ms
# Speed: 7.1ms preprocess, 457.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 504.7ms
# Speed: 5.1ms preprocess, 504.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 937.6ms
# Speed: 10.3ms preprocess, 937.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 482.9ms
# Speed: 7.3ms preprocess, 482.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 497.7ms
# Speed: 8.2ms preprocess, 497.7ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 515.7ms
# Speed: 7.6ms preprocess, 515.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 613.6ms
# Speed: 3.1ms preprocess, 613.6ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 508.1ms
# Speed: 1.8ms preprocess, 508.1ms inference, 5.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 476.4ms
# Speed: 5.6ms preprocess, 476.4ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 640.8ms
# Speed: 11.9ms preprocess, 640.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 438.8ms
# Speed: 4.3ms preprocess, 438.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 388.0ms
# Speed: 7.7ms preprocess, 388.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 405.4ms
# Speed: 10.2ms preprocess, 405.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 398.6ms
# Speed: 7.6ms preprocess, 398.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 405.5ms
# Speed: 10.0ms preprocess, 405.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 399.9ms
# Speed: 7.8ms preprocess, 399.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 399.6ms
# Speed: 7.5ms preprocess, 399.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 418.3ms
# Speed: 7.1ms preprocess, 418.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 385.2ms
# Speed: 8.7ms preprocess, 385.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 386.7ms
# Speed: 7.1ms preprocess, 386.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 395.2ms
# Speed: 7.9ms preprocess, 395.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 386.4ms
# Speed: 8.8ms preprocess, 386.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 408.7ms
# Speed: 4.0ms preprocess, 408.7ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 401.4ms
# Speed: 3.5ms preprocess, 401.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 483.9ms
# Speed: 5.4ms preprocess, 483.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 429.0ms
# Speed: 5.6ms preprocess, 429.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 412.6ms
# Speed: 5.9ms preprocess, 412.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 411.5ms
# Speed: 8.6ms preprocess, 411.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 386.5ms
# Speed: 9.7ms preprocess, 386.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 405.6ms
# Speed: 5.3ms preprocess, 405.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 405.7ms
# Speed: 9.2ms preprocess, 405.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 393.9ms
# Speed: 14.9ms preprocess, 393.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 391.1ms
# Speed: 9.1ms preprocess, 391.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 392.8ms
# Speed: 9.8ms preprocess, 392.8ms inference, 4.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 404.2ms
# Speed: 8.9ms preprocess, 404.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 396.5ms
# Speed: 10.0ms preprocess, 396.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 396.2ms
# Speed: 8.7ms preprocess, 396.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 384.9ms
# Speed: 9.8ms preprocess, 384.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 386.1ms
# Speed: 9.2ms preprocess, 386.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 401.4ms
# Speed: 6.8ms preprocess, 401.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 397.8ms
# Speed: 4.4ms preprocess, 397.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 403.8ms
# Speed: 7.2ms preprocess, 403.8ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 403.2ms
# Speed: 6.5ms preprocess, 403.2ms inference, 2.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 395.6ms
# Speed: 7.8ms preprocess, 395.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 403.8ms
# Speed: 8.8ms preprocess, 403.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 411.7ms
# Speed: 9.9ms preprocess, 411.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 390.2ms
# Speed: 5.5ms preprocess, 390.2ms inference, 4.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 396.5ms
# Speed: 8.9ms preprocess, 396.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 385.6ms
# Speed: 6.9ms preprocess, 385.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 388.8ms
# Speed: 5.8ms preprocess, 388.8ms inference, 3.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 397.7ms
# Speed: 15.8ms preprocess, 397.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 397.6ms
# Speed: 8.6ms preprocess, 397.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 386.4ms
# Speed: 9.0ms preprocess, 386.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 433.9ms
# Speed: 10.4ms preprocess, 433.9ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 407.6ms
# Speed: 8.5ms preprocess, 407.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 391.7ms
# Speed: 5.9ms preprocess, 391.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 427.4ms
# Speed: 4.9ms preprocess, 427.4ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 387.7ms
# Speed: 7.8ms preprocess, 387.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 380.0ms
# Speed: 9.8ms preprocess, 380.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 405.3ms
# Speed: 5.1ms preprocess, 405.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 402.3ms
# Speed: 9.8ms preprocess, 402.3ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 400.7ms
# Speed: 9.0ms preprocess, 400.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 412.0ms
# Speed: 3.2ms preprocess, 412.0ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 396.5ms
# Speed: 8.1ms preprocess, 396.5ms inference, 5.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 395.4ms
# Speed: 10.7ms preprocess, 395.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 395.5ms
# Speed: 1.7ms preprocess, 395.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 509.3ms
# Speed: 3.1ms preprocess, 509.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 404.4ms
# Speed: 10.9ms preprocess, 404.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 389.2ms
# Speed: 9.6ms preprocess, 389.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 508.5ms
# Speed: 5.2ms preprocess, 508.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 397.0ms
# Speed: 5.6ms preprocess, 397.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 422.6ms
# Speed: 4.6ms preprocess, 422.6ms inference, 2.3ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 391.1ms
# Speed: 11.9ms preprocess, 391.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 400.0ms
# Speed: 7.8ms preprocess, 400.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 403.0ms
# Speed: 7.7ms preprocess, 403.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 402.6ms
# Speed: 11.5ms preprocess, 402.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 402.7ms
# Speed: 4.2ms preprocess, 402.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 454.1ms
# Speed: 4.0ms preprocess, 454.1ms inference, 2.7ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 467.7ms
# Speed: 12.0ms preprocess, 467.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 394.4ms
# Speed: 5.3ms preprocess, 394.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 513.9ms
# Speed: 6.6ms preprocess, 513.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 389.6ms
# Speed: 4.6ms preprocess, 389.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 387.2ms
# Speed: 7.2ms preprocess, 387.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 394.3ms
# Speed: 11.1ms preprocess, 394.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 395.4ms
# Speed: 8.4ms preprocess, 395.4ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 406.7ms
# Speed: 0.0ms preprocess, 406.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 391.3ms
# Speed: 8.6ms preprocess, 391.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 376.0ms
# Speed: 7.1ms preprocess, 376.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 405.4ms
# Speed: 10.8ms preprocess, 405.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 411.5ms
# Speed: 9.6ms preprocess, 411.5ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 404.2ms
# Speed: 7.1ms preprocess, 404.2ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 386.2ms
# Speed: 5.1ms preprocess, 386.2ms inference, 5.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 407.4ms
# Speed: 8.5ms preprocess, 407.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 381.4ms
# Speed: 8.3ms preprocess, 381.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 419.9ms
# Speed: 9.8ms preprocess, 419.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 391.4ms
# Speed: 7.5ms preprocess, 391.4ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 393.3ms
# Speed: 6.5ms preprocess, 393.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 400.1ms
# Speed: 2.3ms preprocess, 400.1ms inference, 10.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 407.3ms
# Speed: 7.7ms preprocess, 407.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 408.3ms
# Speed: 6.1ms preprocess, 408.3ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 393.3ms
# Speed: 9.7ms preprocess, 393.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 395.7ms
# Speed: 9.3ms preprocess, 395.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 382.6ms
# Speed: 6.7ms preprocess, 382.6ms inference, 5.3ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 400.1ms
# Speed: 8.5ms preprocess, 400.1ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 388.7ms
# Speed: 7.6ms preprocess, 388.7ms inference, 5.7ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 401.8ms
# Speed: 5.1ms preprocess, 401.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 391.4ms
# Speed: 7.0ms preprocess, 391.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 385.3ms
# Speed: 5.2ms preprocess, 385.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 388.8ms
# Speed: 9.0ms preprocess, 388.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 384.7ms
# Speed: 11.8ms preprocess, 384.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 393.9ms
# Speed: 11.4ms preprocess, 393.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 397.4ms
# Speed: 7.0ms preprocess, 397.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 401.6ms
# Speed: 10.0ms preprocess, 401.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 394.9ms
# Speed: 7.8ms preprocess, 394.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 411.8ms
# Speed: 10.6ms preprocess, 411.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 388.6ms
# Speed: 10.1ms preprocess, 388.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 389.9ms
# Speed: 5.5ms preprocess, 389.9ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 417.2ms
# Speed: 9.5ms preprocess, 417.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 401.8ms
# Speed: 3.7ms preprocess, 401.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 391.5ms
# Speed: 7.9ms preprocess, 391.5ms inference, 5.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 394.4ms
# Speed: 8.1ms preprocess, 394.4ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 392.9ms
# Speed: 6.8ms preprocess, 392.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 393.0ms
# Speed: 7.8ms preprocess, 393.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 386.5ms
# Speed: 9.8ms preprocess, 386.5ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 397.4ms
# Speed: 10.0ms preprocess, 397.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 395.3ms
# Speed: 8.8ms preprocess, 395.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 403.1ms
# Speed: 16.2ms preprocess, 403.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 399.8ms
# Speed: 8.4ms preprocess, 399.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 398.1ms
# Speed: 10.7ms preprocess, 398.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 410.1ms
# Speed: 6.6ms preprocess, 410.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 408.2ms
# Speed: 7.2ms preprocess, 408.2ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 409.1ms
# Speed: 9.5ms preprocess, 409.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 400.7ms
# Speed: 7.5ms preprocess, 400.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 407.2ms
# Speed: 7.5ms preprocess, 407.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 385.4ms
# Speed: 6.0ms preprocess, 385.4ms inference, 4.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 393.1ms
# Speed: 7.4ms preprocess, 393.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 431.6ms
# Speed: 9.4ms preprocess, 431.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 413.3ms
# Speed: 3.1ms preprocess, 413.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 403.8ms
# Speed: 0.0ms preprocess, 403.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 403.5ms
# Speed: 5.1ms preprocess, 403.5ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 378.1ms
# Speed: 14.3ms preprocess, 378.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 398.2ms
# Speed: 11.5ms preprocess, 398.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 405.1ms
# Speed: 8.5ms preprocess, 405.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 396.1ms
# Speed: 8.7ms preprocess, 396.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 412.9ms
# Speed: 10.6ms preprocess, 412.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 408.9ms
# Speed: 7.0ms preprocess, 408.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 391.1ms
# Speed: 9.5ms preprocess, 391.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 396.8ms
# Speed: 9.8ms preprocess, 396.8ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 396.7ms
# Speed: 6.5ms preprocess, 396.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 410.3ms
# Speed: 5.7ms preprocess, 410.3ms inference, 4.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 403.9ms
# Speed: 11.1ms preprocess, 403.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 397.6ms
# Speed: 8.9ms preprocess, 397.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 399.3ms
# Speed: 10.2ms preprocess, 399.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 395.2ms
# Speed: 11.4ms preprocess, 395.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 398.3ms
# Speed: 10.5ms preprocess, 398.3ms inference, 6.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 487.4ms
# Speed: 9.3ms preprocess, 487.4ms inference, 5.7ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 415.9ms
# Speed: 7.2ms preprocess, 415.9ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 396.4ms
# Speed: 7.8ms preprocess, 396.4ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 392.3ms
# Speed: 7.7ms preprocess, 392.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 397.2ms
# Speed: 9.8ms preprocess, 397.2ms inference, 3.7ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 395.8ms
# Speed: 7.2ms preprocess, 395.8ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 387.8ms
# Speed: 8.9ms preprocess, 387.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 379.9ms
# Speed: 8.7ms preprocess, 379.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 403.4ms
# Speed: 6.6ms preprocess, 403.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 401.4ms
# Speed: 11.5ms preprocess, 401.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 423.9ms
# Speed: 6.1ms preprocess, 423.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 422.7ms
# Speed: 15.6ms preprocess, 422.7ms inference, 2.2ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 409.2ms
# Speed: 5.5ms preprocess, 409.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 401.9ms
# Speed: 8.6ms preprocess, 401.9ms inference, 2.3ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 400.3ms
# Speed: 6.8ms preprocess, 400.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 392.2ms
# Speed: 7.7ms preprocess, 392.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 492.1ms
# Speed: 6.8ms preprocess, 492.1ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 404.2ms
# Speed: 6.3ms preprocess, 404.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 499.8ms
# Speed: 7.3ms preprocess, 499.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 563.2ms
# Speed: 15.5ms preprocess, 563.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 496.4ms
# Speed: 7.2ms preprocess, 496.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 813.9ms
# Speed: 9.6ms preprocess, 813.9ms inference, 6.8ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 659.8ms
# Speed: 13.5ms preprocess, 659.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 585.0ms
# Speed: 7.3ms preprocess, 585.0ms inference, 2.8ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 504.6ms
# Speed: 8.9ms preprocess, 504.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 555.2ms
# Speed: 6.3ms preprocess, 555.2ms inference, 4.8ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 497.0ms
# Speed: 8.0ms preprocess, 497.0ms inference, 3.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 543.9ms
# Speed: 7.8ms preprocess, 543.9ms inference, 9.9ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 478.4ms
# Speed: 8.3ms preprocess, 478.4ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 537.1ms
# Speed: 8.3ms preprocess, 537.1ms inference, 4.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 554.0ms
# Speed: 7.5ms preprocess, 554.0ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 514.1ms
# Speed: 12.4ms preprocess, 514.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 546.0ms
# Speed: 11.7ms preprocess, 546.0ms inference, 2.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 558.5ms
# Speed: 5.8ms preprocess, 558.5ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 383.3ms
# Speed: 6.0ms preprocess, 383.3ms inference, 9.7ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 515.5ms
# Speed: 9.7ms preprocess, 515.5ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 553.2ms
# Speed: 8.7ms preprocess, 553.2ms inference, 5.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 548.5ms
# Speed: 9.3ms preprocess, 548.5ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 483.3ms
# Speed: 3.6ms preprocess, 483.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 407.7ms
# Speed: 1.2ms preprocess, 407.7ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 555.7ms
# Speed: 8.4ms preprocess, 555.7ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 495.4ms
# Speed: 9.8ms preprocess, 495.4ms inference, 2.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 461.6ms
# Speed: 7.4ms preprocess, 461.6ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 528.4ms
# Speed: 8.7ms preprocess, 528.4ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 536.8ms
# Speed: 8.7ms preprocess, 536.8ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 538.7ms
# Speed: 6.6ms preprocess, 538.7ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 535.7ms
# Speed: 8.7ms preprocess, 535.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 430.9ms
# Speed: 8.6ms preprocess, 430.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 528.6ms
# Speed: 7.1ms preprocess, 528.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 600.1ms
# Speed: 12.9ms preprocess, 600.1ms inference, 4.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 773.6ms
# Speed: 15.2ms preprocess, 773.6ms inference, 5.2ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 571.6ms
# Speed: 4.7ms preprocess, 571.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 406.2ms
# Speed: 7.7ms preprocess, 406.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 388.1ms
# Speed: 8.5ms preprocess, 388.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 397.5ms
# Speed: 8.8ms preprocess, 397.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 419.9ms
# Speed: 9.8ms preprocess, 419.9ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 396.2ms
# Speed: 6.5ms preprocess, 396.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 391.6ms
# Speed: 9.7ms preprocess, 391.6ms inference, 5.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 564.2ms
# Speed: 11.9ms preprocess, 564.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 512.0ms
# Speed: 7.6ms preprocess, 512.0ms inference, 7.8ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 565.4ms
# Speed: 9.0ms preprocess, 565.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 421.8ms
# Speed: 15.0ms preprocess, 421.8ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 374.0ms
# Speed: 10.1ms preprocess, 374.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 409.3ms
# Speed: 11.0ms preprocess, 409.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 392.2ms
# Speed: 8.6ms preprocess, 392.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 409.6ms
# Speed: 10.2ms preprocess, 409.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 417.0ms
# Speed: 8.8ms preprocess, 417.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 568.2ms
# Speed: 7.1ms preprocess, 568.2ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 425.0ms
# Speed: 6.5ms preprocess, 425.0ms inference, 9.9ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 380.2ms
# Speed: 7.0ms preprocess, 380.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 376.2ms
# Speed: 5.7ms preprocess, 376.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 406.1ms
# Speed: 7.5ms preprocess, 406.1ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 399.7ms
# Speed: 10.6ms preprocess, 399.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 394.9ms
# Speed: 11.9ms preprocess, 394.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 392.8ms
# Speed: 7.3ms preprocess, 392.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 387.9ms
# Speed: 16.8ms preprocess, 387.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 540.1ms
# Speed: 15.0ms preprocess, 540.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 395.6ms
# Speed: 15.0ms preprocess, 395.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 450.6ms
# Speed: 5.2ms preprocess, 450.6ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 578.1ms
# Speed: 5.3ms preprocess, 578.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 393.0ms
# Speed: 11.3ms preprocess, 393.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 406.3ms
# Speed: 4.8ms preprocess, 406.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 385.9ms
# Speed: 6.0ms preprocess, 385.9ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 387.1ms
# Speed: 8.7ms preprocess, 387.1ms inference, 5.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 402.5ms
# Speed: 7.5ms preprocess, 402.5ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 401.0ms
# Speed: 12.3ms preprocess, 401.0ms inference, 6.9ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 405.1ms
# Speed: 14.6ms preprocess, 405.1ms inference, 7.9ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 394.9ms
# Speed: 7.1ms preprocess, 394.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 404.7ms
# Speed: 8.8ms preprocess, 404.7ms inference, 2.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 477.4ms
# Speed: 9.1ms preprocess, 477.4ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 450.0ms
# Speed: 8.3ms preprocess, 450.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 457.3ms
# Speed: 12.9ms preprocess, 457.3ms inference, 4.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 402.8ms
# Speed: 7.0ms preprocess, 402.8ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 389.6ms
# Speed: 10.0ms preprocess, 389.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 383.8ms
# Speed: 9.7ms preprocess, 383.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 393.2ms
# Speed: 9.9ms preprocess, 393.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 400.9ms
# Speed: 9.9ms preprocess, 400.9ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 382.3ms
# Speed: 4.1ms preprocess, 382.3ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 396.0ms
# Speed: 7.0ms preprocess, 396.0ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 379.9ms
# Speed: 8.1ms preprocess, 379.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 375.4ms
# Speed: 5.8ms preprocess, 375.4ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 393.9ms
# Speed: 4.2ms preprocess, 393.9ms inference, 2.3ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 402.4ms
# Speed: 7.7ms preprocess, 402.4ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 367.2ms
# Speed: 6.7ms preprocess, 367.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 punch, 397.5ms
# ...
#
# 0: 512x800 (no detections), 419.0ms
# Speed: 9.7ms preprocess, 419.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 413.5ms
# Speed: 9.7ms preprocess, 413.5ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 407.7ms
# Speed: 7.9ms preprocess, 407.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 415.6ms
# Speed: 3.9ms preprocess, 415.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 395.7ms
# Speed: 11.6ms preprocess, 395.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 429.0ms
# Speed: 8.1ms preprocess, 429.0ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 416.9ms
# Speed: 5.8ms preprocess, 416.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 420.0ms
# Speed: 7.9ms preprocess, 420.0ms inference, 4.9ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 425.4ms
# Speed: 7.9ms preprocess, 425.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 420.4ms
# Speed: 13.6ms preprocess, 420.4ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 404.4ms
# Speed: 9.0ms preprocess, 404.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 411.6ms
# Speed: 9.9ms preprocess, 411.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 416.5ms
# Speed: 7.7ms preprocess, 416.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 412.9ms
# Speed: 6.7ms preprocess, 412.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 417.7ms
# Speed: 8.7ms preprocess, 417.7ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 428.1ms
# Speed: 9.8ms preprocess, 428.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 411.3ms
# Speed: 7.3ms preprocess, 411.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 419.6ms
# Speed: 7.9ms preprocess, 419.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 413.9ms
# Speed: 6.3ms preprocess, 413.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 414.9ms
# Speed: 8.4ms preprocess, 414.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 560.5ms
# Speed: 10.7ms preprocess, 560.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 936.0ms
# Speed: 34.7ms preprocess, 936.0ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 618.3ms
# Speed: 13.2ms preprocess, 618.3ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 689.5ms
# Speed: 12.0ms preprocess, 689.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 819.7ms
# Speed: 14.7ms preprocess, 819.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 429.6ms
# Speed: 10.5ms preprocess, 429.6ms inference, 10.4ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 513.2ms
# Speed: 10.8ms preprocess, 513.2ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 489.2ms
# Speed: 16.3ms preprocess, 489.2ms inference, 5.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 447.6ms
# Speed: 6.5ms preprocess, 447.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 445.2ms
# Speed: 7.8ms preprocess, 445.2ms inference, 2.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 408.1ms
# Speed: 8.4ms preprocess, 408.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 414.5ms
# Speed: 5.3ms preprocess, 414.5ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 408.5ms
# Speed: 9.7ms preprocess, 408.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 412.3ms
# Speed: 7.7ms preprocess, 412.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 430.0ms
# Speed: 8.7ms preprocess, 430.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 405.5ms
# Speed: 7.2ms preprocess, 405.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 410.8ms
# Speed: 8.7ms preprocess, 410.8ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 461.1ms
# Speed: 5.5ms preprocess, 461.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 415.6ms
# Speed: 9.8ms preprocess, 415.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 422.4ms
# Speed: 6.6ms preprocess, 422.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 478.7ms
# Speed: 8.3ms preprocess, 478.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 562.7ms
# Speed: 16.2ms preprocess, 562.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 749.8ms
# Speed: 5.0ms preprocess, 749.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 717.5ms
# Speed: 11.3ms preprocess, 717.5ms inference, 7.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 670.1ms
# Speed: 11.9ms preprocess, 670.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 802.3ms
# Speed: 9.5ms preprocess, 802.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 1027.1ms
# Speed: 9.6ms preprocess, 1027.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 414.9ms
# Speed: 10.0ms preprocess, 414.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 324.8ms
# Speed: 10.3ms preprocess, 324.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 325.1ms
# Speed: 5.0ms preprocess, 325.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 314.8ms
# Speed: 10.1ms preprocess, 314.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 350.1ms
# Speed: 10.1ms preprocess, 350.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 344.6ms
# Speed: 10.4ms preprocess, 344.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 357.3ms
# Speed: 7.6ms preprocess, 357.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 364.2ms
# Speed: 12.6ms preprocess, 364.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 341.0ms
# Speed: 13.7ms preprocess, 341.0ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 343.6ms
# Speed: 11.1ms preprocess, 343.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 325.5ms
# Speed: 8.5ms preprocess, 325.5ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 345.8ms
# Speed: 8.2ms preprocess, 345.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 392.6ms
# Speed: 8.7ms preprocess, 392.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 311.4ms
# Speed: 10.9ms preprocess, 311.4ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 327.8ms
# Speed: 9.0ms preprocess, 327.8ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 295.3ms
# Speed: 7.5ms preprocess, 295.3ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 309.9ms
# Speed: 8.1ms preprocess, 309.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 248.2ms
# Speed: 6.5ms preprocess, 248.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 258.9ms
# Speed: 7.1ms preprocess, 258.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 346.3ms
# Speed: 7.6ms preprocess, 346.3ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 295.7ms
# Speed: 8.4ms preprocess, 295.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 267.4ms
# Speed: 7.0ms preprocess, 267.4ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 264.0ms
# Speed: 7.9ms preprocess, 264.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 266.1ms
# Speed: 7.1ms preprocess, 266.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 273.5ms
# Speed: 7.5ms preprocess, 273.5ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 303.0ms
# Speed: 8.9ms preprocess, 303.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 251.5ms
# Speed: 8.1ms preprocess, 251.5ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 254.2ms
# Speed: 5.1ms preprocess, 254.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 249.6ms
# Speed: 7.6ms preprocess, 249.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 241.9ms
# Speed: 7.1ms preprocess, 241.9ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 310.6ms
# Speed: 8.5ms preprocess, 310.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 238.6ms
# Speed: 7.4ms preprocess, 238.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 236.6ms
# Speed: 7.2ms preprocess, 236.6ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 239.9ms
# Speed: 7.5ms preprocess, 239.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 248.2ms
# Speed: 7.5ms preprocess, 248.2ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 271.8ms
# Speed: 8.0ms preprocess, 271.8ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 265.5ms
# Speed: 7.0ms preprocess, 265.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 243.4ms
# Speed: 7.7ms preprocess, 243.4ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 245.5ms
# Speed: 6.5ms preprocess, 245.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 245.0ms
# Speed: 7.5ms preprocess, 245.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 244.8ms
# Speed: 10.2ms preprocess, 244.8ms inference, 2.7ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 311.6ms
# Speed: 7.6ms preprocess, 311.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 257.0ms
# Speed: 8.7ms preprocess, 257.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 271.2ms
# Speed: 7.7ms preprocess, 271.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 260.6ms
# Speed: 8.2ms preprocess, 260.6ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 267.2ms
# Speed: 7.0ms preprocess, 267.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 268.1ms
# Speed: 7.7ms preprocess, 268.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 304.3ms
# Speed: 8.5ms preprocess, 304.3ms inference, 2.3ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 262.3ms
# Speed: 6.7ms preprocess, 262.3ms inference, 2.7ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 269.9ms
# Speed: 7.3ms preprocess, 269.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 263.1ms
# Speed: 7.1ms preprocess, 263.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 258.2ms
# Speed: 7.5ms preprocess, 258.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 325.1ms
# Speed: 6.9ms preprocess, 325.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 245.0ms
# Speed: 7.5ms preprocess, 245.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 258.2ms
# Speed: 7.9ms preprocess, 258.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 256.5ms
# Speed: 8.2ms preprocess, 256.5ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 251.6ms
# Speed: 7.1ms preprocess, 251.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 244.8ms
# Speed: 7.5ms preprocess, 244.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 1 kick, 316.0ms
# Speed: 7.7ms preprocess, 316.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 260.4ms
# Speed: 8.1ms preprocess, 260.4ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 255.8ms
# Speed: 7.9ms preprocess, 255.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 255.5ms
# Speed: 6.7ms preprocess, 255.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 245.3ms
# Speed: 6.7ms preprocess, 245.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 302.3ms
# Speed: 8.5ms preprocess, 302.3ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 259.9ms
# Speed: 5.0ms preprocess, 259.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 249.9ms
# Speed: 5.0ms preprocess, 249.9ms inference, 5.1ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 244.5ms
# Speed: 10.3ms preprocess, 244.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 335.1ms
# Speed: 6.5ms preprocess, 335.1ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 252.0ms
# Speed: 8.4ms preprocess, 252.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 251.4ms
# Speed: 9.6ms preprocess, 251.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 244.3ms
# Speed: 7.5ms preprocess, 244.3ms inference, 4.6ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 285.0ms
# Speed: 8.2ms preprocess, 285.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
#
# 0: 512x800 (no detections), 388.2ms
# Speed: 5.1ms preprocess, 388.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 800)
# Total Punches: 14
# Total Kicks: 6
