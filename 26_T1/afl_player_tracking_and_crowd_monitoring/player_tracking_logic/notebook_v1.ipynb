# %%
# !nvidia-smi
# Out:
# Fri Apr  3 08:53:47 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
from IPython.display import Image, display
import os
import random

# %%
# !ls
# Out:
# drive  sample_data

# %%
data_yaml = """
train: /content/drive/MyDrive/data/train/images
val: /content/drive/MyDrive/data/test/images
test: /content/drive/MyDrive/data/test/images

names:
  0: CAR
  1: GCS
  2: REF
"""

# %%
with open("/content/data.yaml", "w") as f:
    f.write(data_yaml)

# %%
model = YOLO("yolo11s.pt")
model.train(data="/content/data.yaml",epochs=60,imgsz=640)
# Out:
# ...
# Ultralytics 8.4.33 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model=YOLO("/content/runs/detect/train/weights/best.pt")
results = model.predict(
    source="/content/drive/MyDrive/data/test/images",
    conf=0.3,
    save=False
)
# Out:
# image 1/20 /content/drive/MyDrive/data/test/images/2a43e72c-frame_0154.jpg: 416x640 8 CARs, 5 GCSs, 4 REFs, 88.0ms
# image 2/20 /content/drive/MyDrive/data/test/images/2d86106f-frame_0099.jpg: 416x640 8 CARs, 6 GCSs, 1 REF, 12.1ms
# image 3/20 /content/drive/MyDrive/data/test/images/31d53c1f-frame_0125.jpg: 416x640 4 CARs, 4 GCSs, 1 REF, 12.0ms
# image 4/20 /content/drive/MyDrive/data/test/images/3aeed16d-frame_0172.jpg: 416x640 3 CARs, 7 GCSs, 1 REF, 12.0ms
# image 5/20 /content/drive/MyDrive/data/test/images/51f0596c-frame_0116.jpg: 416x640 9 CARs, 5 GCSs, 2 REFs, 12.0ms
# image 6/20 /content/drive/MyDrive/data/test/images/558629f6-frame_0088.jpg: 416x640 6 CARs, 9 GCSs, 11.9ms
# image 7/20 /content/drive/MyDrive/data/test/images/69c09bfc-frame_0161.jpg: 416x640 5 CARs, 4 GCSs, 2 REFs, 12.0ms
# image 8/20 /content/drive/MyDrive/data/test/images/8c5c33e7-frame_0053.jpg: 416x640 1 GCS, 11.9ms
# ...
