# %% [markdown]
# ## **YOLOv8 Model Training and Video Processing** ##

# %% [markdown]
# This notebook demonstrates how to train a YOLOv8 model with a custom dataset and use the trained model to process and annotate a video.

# %% [markdown]
# **Imports and Setup**

# %%
# !pip install -r https://raw.githubusercontent.com/rissicay/redback-orion/main/Player_Tracking/greyhound_tracking/requirements.txt


import os
import cv2
from ultralytics import YOLO
import supervision as sv

# %% [markdown]
# os: For file and directory operations.
#
# cv2: OpenCV library for video processing.
#
# YOLO from ultralytics: YOLOv8 model for object detection.
#
# supervision as sv: For object detection and annotation.

# %% [markdown]
# **Step 1: Train the YOLO Model**

# %%
def train_yolo():
    # Initialize the YOLO model with pretrained weights
    model = YOLO("yolov8n.pt")  #...use m or l  
    # Train the model with your custom dataset
    model.train(
        data="../data/greyhound_racing_dataset/data.yaml",  # path to your data configuration file
        epochs=10,         # number of training epochs
        imgsz=640,         # input image size
        batch=16,          # batch size
        name="yolov8n-greyhound"  # name of the training run
    )

# %% [markdown]
# train_yolo() Function:
#
# 1. Initializes the YOLO model with pre-trained weights (yolov8n.pt).
#
# 2. Trains the model using the specified dataset configuration (data.yaml), number of epochs, image size, batch size, and training run name.
#
# Note: Ensure that data.yaml is correctly configured with paths to training and validation data.

# %% [markdown]
# **Step 2: Process Video using the Trained YOLO Model**

# %%
def process_video(video_path, output_path, model_path):
    # Load the fine-tuned YOLO model
    model = YOLO(model_path)

    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Verify the output directory and permissions
    output_dir = os.path.dirname(output_path)
    if output_dir and not os.path.exists(output_dir):
        os.makedirs(output_dir)
    if output_dir and not os.access(output_dir, os.W_OK):
        raise PermissionError(f"Write permission denied for the directory {output_dir}")

    assert cap.isOpened(), "Error reading video file"

    # Get video properties
    w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

    # Initialize VideoWriter with a successful FourCC code
    fourcc_code = cv2.VideoWriter_fourcc(*"mp4v")
    video_writer = cv2.VideoWriter(output_path, fourcc_code, fps, (w, h))

    if not video_writer.isOpened():
        raise IOError(f"Error initializing video writer with path {output_path}")

    # Custom function to filter greyhound detections
    def filter_greyhound_detections(detections):
        greyhound_class_id = 0  # Change to the appropriate class ID for greyhounds
        mask = detections.class_id == greyhound_class_id
        filtered_detections = sv.Detections(
            xyxy=detections.xyxy[mask],
            confidence=detections.confidence[mask],
            class_id=detections.class_id[mask]
        )
        return filtered_detections

    # Process video frames
    box_annotator = sv.BoxAnnotator(thickness=4)
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            print("Video frame is empty or video processing has been successfully completed.")
            break

        # Perform object detection
        results = model(frame, imgsz=1280)

        # Extract bounding boxes, confidences, and class IDs
        boxes = results[0].boxes.xyxy.cpu().numpy()
        confidences = results[0].boxes.conf.cpu().numpy()
        class_ids = results[0].boxes.cls.cpu().numpy().astype(int)

        # Create detections object
        detections = sv.Detections(
            xyxy=boxes,
            confidence=confidences,
            class_id=class_ids
        )

        # # Filter greyhound detections
        # greyhound_detections = filter_greyhound_detections(detections)

        # Annotate the frame
        annotated_frame = box_annotator.annotate(scene=frame, detections=detections)

        # Write the processed frame to the output video
        video_writer.write(annotated_frame)

    cap.release()
    video_writer.release()
    cv2.destroyAllWindows()

    print(f"Processed video saved to {output_path}")

# %% [markdown]
# **process_video() Function:**

# %% [markdown]
# 1. Loads the fine-tuned YOLO model from the specified model_path.
#
# 2. Opens the input video file and checks directory permissions for saving the output.
#
# 3. Initializes VideoWriter to save the processed video.
#
# 4. filter_greyhound_detections(): Filters detections to include only greyhounds based on their class ID.

# %% [markdown]
# **Processes each video frame:**

# %% [markdown]
# 1. Performs object detection.
#
# 2. Extracts and filters detections.
#
# 3. Annotates frames with bounding boxes.
#
# 4. Writes annotated frames to the output video file.

# %% [markdown]
# **Running the Script**

# %%
# Train the model (uncomment the line below to train)
# train_yolo()

# Path to your greyhound racing video
GREYHOUND_RACING_VIDEO_PATH = "../data/raw_videos/20240722NOTG06_V.mp4"
# Output path for the processed video
OUTPUT_VIDEO_PATH = "./output/greyhound_racing_output.mp4"
# Path to the fine-tuned model weights
MODEL_PATH = "./runs/detect/yolov8n-greyhound/weights/best.pt"

# Process the video using the trained model
process_video(GREYHOUND_RACING_VIDEO_PATH, OUTPUT_VIDEO_PATH, MODEL_PATH)
# Out:
# 0: 736x1280 (no detections), 46.5ms
# Speed: 4.5ms preprocess, 46.5ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 41.3ms
# Speed: 4.6ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 61.4ms
# Speed: 2.6ms preprocess, 61.4ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 43.6ms
# Speed: 2.4ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 55.4ms
# Speed: 2.1ms preprocess, 55.4ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 42.8ms
# Speed: 2.2ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 50.7ms
# Speed: 2.2ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 41.0ms
# Speed: 2.1ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 53.9ms
# Speed: 2.2ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 47.7ms
# Speed: 2.1ms preprocess, 47.7ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 54.4ms
# Speed: 2.4ms preprocess, 54.4ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 58.4ms
# Speed: 2.1ms preprocess, 58.4ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 49.5ms
# Speed: 2.3ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 57.4ms
# Speed: 2.3ms preprocess, 57.4ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 58.2ms
# Speed: 2.2ms preprocess, 58.2ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 48.0ms
# Speed: 2.8ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 44.2ms
# Speed: 2.3ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 64.1ms
# Speed: 2.3ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 57.8ms
# Speed: 4.1ms preprocess, 57.8ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 72.4ms
# Speed: 2.5ms preprocess, 72.4ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 77.7ms
# Speed: 2.5ms preprocess, 77.7ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 49.1ms
# Speed: 2.1ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 42.9ms
# Speed: 2.1ms preprocess, 42.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 46.0ms
# Speed: 2.3ms preprocess, 46.0ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 50.3ms
# Speed: 2.3ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 70.4ms
# Speed: 4.3ms preprocess, 70.4ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 54.6ms
# Speed: 2.2ms preprocess, 54.6ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 52.8ms
# Speed: 4.2ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 43.7ms
# Speed: 4.2ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 73.8ms
# Speed: 2.2ms preprocess, 73.8ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 69.7ms
# Speed: 2.3ms preprocess, 69.7ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 56.3ms
# Speed: 2.2ms preprocess, 56.3ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 49.0ms
# Speed: 2.2ms preprocess, 49.0ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 52.2ms
# Speed: 2.2ms preprocess, 52.2ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 60.7ms
# Speed: 2.4ms preprocess, 60.7ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections),
1ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 52.1ms
# Speed: 2.1ms preprocess, 52.1ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 48.0ms
# Speed: 2.4ms preprocess, 48.0ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 71.8ms
# Speed: 2.6ms preprocess, 71.8ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 56.2ms
# Speed: 2.3ms preprocess, 56.2ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 40.9ms
# Speed: 3.9ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 52.5ms
# Speed: 4.1ms preprocess, 52.5ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 52.3ms
# Speed: 2.2ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 56.5ms
# Speed: 4.0ms preprocess, 56.5ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 40.8ms
# Speed: 2.2ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 42.6ms
# Speed: 2.3ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 54.7ms
# Speed: 2.3ms preprocess, 54.7ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 40.2ms
# Speed: 2.5ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 55.1ms
# Speed: 2.5ms preprocess, 55.1ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 40.2ms
# Speed: 2.3ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 44.1ms
# Speed: 2.9ms preprocess, 44.1ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 45.7ms
# Speed: 2.6ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 76.7ms
# Speed: 2.1ms preprocess, 76.7ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 52.1ms
# Speed: 2.3ms preprocess, 52.1ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 66.1ms
# Speed: 2.1ms preprocess, 66.1ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 49.8ms
# Speed: 4.2ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 47.4ms
# Speed: 4.2ms preprocess, 47.4ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 55.5ms
# Speed: 2.8ms preprocess, 55.5ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 39.7ms
# Speed: 2.2ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 62.3ms
# Speed: 2.6ms preprocess, 62.3ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 40.1ms
# Speed: 2.1ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 40.4ms
# Speed: 4.6ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 44.1ms
# Speed: 2.3ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 51.5ms
# Speed: 4.3ms preprocess, 51.5ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 66.6ms
# Speed: 4.0ms preprocess, 66.6ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 68.4ms
# Speed: 2.1ms preprocess, 68.4ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 65.9ms
# Speed: 4.4ms preprocess, 65.9ms inference, 0.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 63.2ms
# ...
# Speed: 2.4ms preprocess, 69.2ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.6ms
# Speed: 2.5ms preprocess, 71.6ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 69.6ms
# Speed: 2.4ms preprocess, 69.6ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 78.1ms
# Speed: 4.1ms preprocess, 78.1ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 79.1ms
# Speed: 4.1ms preprocess, 79.1ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 79.3ms
# Speed: 4.0ms preprocess, 79.3ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 78.8ms
# Speed: 3.9ms preprocess, 78.8ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 40.7ms
# Speed: 4.1ms preprocess, 40.7ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 38.3ms
# Speed: 2.3ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 39.8ms
# Speed: 2.4ms preprocess, 39.8ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 84.2ms
# Speed: 4.8ms preprocess, 84.2ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.6ms
# Speed: 3.8ms preprocess, 73.6ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.9ms
# Speed: 4.0ms preprocess, 73.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 55.1ms
# Speed: 4.1ms preprocess, 55.1ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 52.4ms
# Speed: 3.8ms preprocess, 52.4ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 75.2ms
# Speed: 2.4ms preprocess, 75.2ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 70.1ms
# Speed: 2.5ms preprocess, 70.1ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.3ms
# Speed: 2.3ms preprocess, 72.3ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 69.7ms
# Speed: 2.3ms preprocess, 69.7ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.0ms
# Speed: 4.1ms preprocess, 73.0ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.3ms
# Speed: 2.3ms preprocess, 71.3ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 69.8ms
# Speed: 2.4ms preprocess, 69.8ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 70.0ms
# Speed: 2.3ms preprocess, 70.0ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 79.9ms
# Speed: 2.4ms preprocess, 79.9ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.9ms
# Speed: 2.6ms preprocess, 71.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.9ms
# Speed: 2.3ms preprocess, 71.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.8ms
# Speed: 2.3ms preprocess, 71.8ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.1ms
# Speed: 2.9ms preprocess, 73.1ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 70.3ms
# Speed: 2.4ms preprocess, 70.3ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.6ms
# Speed: 2.4ms preprocess, 71.6ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 70.5ms
# Speed: 2.4ms preprocess, 70.5ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 69.9ms
# Speed: 2.4ms preprocess, 69.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.2ms
# Speed: 2.3ms preprocess, 72.2ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.8ms
# Speed: 2.5ms preprocess, 71.8ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.8ms
# Speed: 2.3ms preprocess, 71.8ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 75.7ms
# Speed: 2.3ms preprocess, 75.7ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 75.7ms
# Speed: 3.2ms preprocess, 75.7ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.4ms
# Speed: 2.5ms preprocess, 73.4ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.4ms
# Speed: 2.4ms preprocess, 73.4ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.6ms
# Speed: 2.4ms preprocess, 71.6ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.0ms
# Speed: 2.6ms preprocess, 73.0ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.1ms
# Speed: 2.3ms preprocess, 72.1ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.5ms
# Speed: 2.4ms preprocess, 73.5ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 78.1ms
# Speed: 4.2ms preprocess, 78.1ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.5ms
# Speed: 4.0ms preprocess, 73.5ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.3ms
# Speed: 2.3ms preprocess, 73.3ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.8ms
# Speed: 2.3ms preprocess, 72.8ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 78.8ms
# Speed: 2.3ms preprocess, 78.8ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 75.0ms
# Speed: 2.5ms preprocess, 75.0ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.3ms
# Speed: 2.4ms preprocess, 72.3ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.8ms
# Speed: 2.4ms preprocess, 73.8ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.9ms
# Speed: 2.5ms preprocess, 73.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 68.1ms
# Speed: 2.3ms preprocess, 68.1ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.4ms
# Speed: 2.3ms preprocess, 73.4ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.5ms
# Speed: 2.3ms preprocess, 72.5ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.5ms
# Speed: 2.4ms preprocess, 72.5ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.6ms
# Speed: 2.3ms preprocess, 72.6ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.0ms
# Speed: 2.5ms preprocess, 73.0ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.9ms
# Speed: 2.5ms preprocess, 72.9ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 75.2ms
# Speed: 2.5ms preprocess, 75.2ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 42.1ms
# Speed: 2.7ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 38.4ms
# Speed: 2.1ms preprocess, 38.4ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 40.4ms
# Speed: 2.5ms preprocess, 40.4ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 79.0ms
# Speed: 4.2ms preprocess, 79.0ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.1ms
# Speed: 2.3ms preprocess, 71.1ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.6ms
# Speed: 2.4ms preprocess, 73.6ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.2ms
# Speed: 2.4ms preprocess, 72.2ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.1ms
# Speed: 2.3ms preprocess, 71.1ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.0ms
# Speed: 3.0ms preprocess, 72.0ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.4ms
# Speed: 2.4ms preprocess, 72.4ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.6ms
# Speed: 2.4ms preprocess, 72.6ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 74.3ms
# Speed: 4.1ms preprocess, 74.3ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 76.8ms
# Speed: 2.8ms preprocess, 76.8ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 84.2ms
# Speed: 4.0ms preprocess, 84.2ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.3ms
# Speed: 2.3ms preprocess, 71.3ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 75.9ms
# Speed: 4.1ms preprocess, 75.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.5ms
# Speed: 2.4ms preprocess, 72.5ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.7ms
# Speed: 4.1ms preprocess, 72.7ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 75.2ms
# Speed: 2.3ms preprocess, 75.2ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.4ms
# Speed: 3.2ms preprocess, 73.4ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.4ms
# Speed: 2.3ms preprocess, 71.4ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.7ms
# Speed: 2.6ms preprocess, 72.7ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.7ms
# Speed: 2.5ms preprocess, 73.7ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 74.6ms
# Speed: 2.7ms preprocess, 74.6ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 75.2ms
# Speed: 2.5ms preprocess, 75.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 78.2ms
# Speed: 4.3ms preprocess, 78.2ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.7ms
# Speed: 3.0ms preprocess, 72.7ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 74.2ms
# Speed: 3.1ms preprocess, 74.2ms inference, 0.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.4ms
# Speed: 2.4ms preprocess, 72.4ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.4ms
# Speed: 2.3ms preprocess, 73.4ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.8ms
# Speed: 2.4ms preprocess, 73.8ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.8ms
# Speed: 2.7ms preprocess, 72.8ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.1ms
# Speed: 2.6ms preprocess, 72.1ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.5ms
# Speed: 2.7ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 74.2ms
# Speed: 2.4ms preprocess, 74.2ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 74.4ms
# Speed: 2.3ms preprocess, 74.4ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 74.2ms
# Speed: 2.3ms preprocess, 74.2ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 77.6ms
# Speed: 2.3ms preprocess, 77.6ms inference, 0.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 75.4ms
# Speed: 2.5ms preprocess, 75.4ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.9ms
# Speed: 2.3ms preprocess, 72.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 75.2ms
# Speed: 4.1ms preprocess, 75.2ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.1ms
# Speed: 2.4ms preprocess, 73.1ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 75.4ms
# Speed: 2.6ms preprocess, 75.4ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.0ms
# Speed: 4.3ms preprocess, 71.0ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.7ms
# Speed: 2.3ms preprocess, 71.7ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 76.0ms
# Speed: 4.1ms preprocess, 76.0ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.5ms
# Speed: 2.7ms preprocess, 72.5ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.3ms
# Speed: 2.3ms preprocess, 73.3ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 73.5ms
# Speed: 2.3ms preprocess, 73.5ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 76.0ms
# Speed: 2.3ms preprocess, 76.0ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 74.8ms
# Speed: 2.4ms preprocess, 74.8ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 71.2ms
# Speed: 2.5ms preprocess, 71.2ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 72.0ms
# Speed: 2.4ms preprocess, 72.0ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 78.8ms
# Speed: 4.2ms preprocess, 78.8ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 38.9ms
# Speed: 4.0ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 38.6ms
# Speed: 2.1ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 41.7ms
# Speed: 2.2ms preprocess, 41.7ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 38.5ms
# Speed: 2.1ms preprocess, 38.5ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 38.3ms
# Speed: 2.1ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 38.6ms
# Speed: 2.1ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 38.3ms
# Speed: 2.4ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 38.5ms
# Speed: 2.2ms preprocess, 38.5ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 48.5ms
# Speed: 2.1ms preprocess, 48.5ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 rail, 38.7ms
# Speed: 2.0ms preprocess, 38.7ms inference, 0.4ms postprocess per image at shape (1, 3, 736, 1280)
# Video frame is empty or video processing has been successfully completed.
# Processed video saved to ./output/greyhound_racing_output.mp4

# %% [markdown]
# Train the Model: Uncomment the train_yolo() call to train the model.

# %% [markdown]
# Process the Video: Specify paths for the input video, output video, and the fine-tuned model, and then call process_video() to process and annotate the video.
